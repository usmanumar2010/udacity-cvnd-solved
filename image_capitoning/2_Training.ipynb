# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, you will train your CNN-RNN model.
#
# You are welcome and encouraged to try out many different architectures and hyperparameters when searching for a good model.
#
# This does have the potential to make the project quite messy!  Before submitting your project, make sure that you clean up:
# - the code you write in this notebook.  The notebook should describe how to train a single CNN-RNN architecture, corresponding to your final choice of hyperparameters.  You should structure the notebook so that the reviewer can replicate your results by running the code in this notebook.
# - the output of the code cell in **Step 2**.  The output should show the output obtained when training the model from scratch.
#
# This notebook **will be graded**.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Training Setup
# - [Step 2](#step2): Train your Model
# - [Step 3](#step3): (Optional) Validate your Model

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Training Setup
#
# In this step of the notebook, you will customize the training of your CNN-RNN model by specifying hyperparameters and setting other options that are important to the training procedure.  The values you set now will be used when training your model in **Step 2** below.
#
# You should only amend blocks of code that are preceded by a `TODO` statement.  **Any code blocks that are not preceded by a `TODO` statement should not be modified**.
#
# ### Task #1
#
# Begin by setting the following variables:
# - `batch_size` - the batch size of each training batch.  It is the number of image-caption pairs used to amend the model weights in each training step.
# - `vocab_threshold` - the minimum word count threshold.  Note that a larger threshold will result in a smaller vocabulary, whereas a smaller threshold will include rarer words and result in a larger vocabulary.
# - `vocab_from_file` - a Boolean that decides whether to load the vocabulary from file.
# - `embed_size` - the dimensionality of the image and word embeddings.
# - `hidden_size` - the number of features in the hidden state of the RNN decoder.
# - `num_epochs` - the number of epochs to train the model.  We recommend that you set `num_epochs=3`, but feel free to increase or decrease this number as you wish.  [This paper](https://arxiv.org/pdf/1502.03044.pdf) trained a captioning model on a single state-of-the-art GPU for 3 days, but you'll soon see that you can get reasonable results in a matter of a few hours!  (_But of course, if you want your model to compete with current research, you will have to train for much longer._)
# - `save_every` - determines how often to save the model weights.  We recommend that you set `save_every=1`, to save the model weights after each epoch.  This way, after the `i`th epoch, the encoder and decoder weights will be saved in the `models/` folder as `encoder-i.pkl` and `decoder-i.pkl`, respectively.
# - `print_every` - determines how often to print the batch loss to the Jupyter notebook while training.  Note that you **will not** observe a monotonic decrease in the loss function while training - this is perfectly fine and completely expected!  You are encouraged to keep this at its default value of `100` to avoid clogging the notebook, but feel free to change it.
# - `log_file` - the name of the text file containing - for every step - how the loss and perplexity evolved during training.
#
# If you're not sure where to begin to set some of the values above, you can peruse [this paper](https://arxiv.org/pdf/1502.03044.pdf) and [this paper](https://arxiv.org/pdf/1411.4555.pdf) for useful guidance!  **To avoid spending too long on this notebook**, you are encouraged to consult these suggested research papers to obtain a strong initial guess for which hyperparameters are likely to work best.  Then, train a single model, and proceed to the next notebook (**3_Inference.ipynb**).  If you are unhappy with your performance, you can return to this notebook to tweak the hyperparameters (and/or the architecture in **model.py**) and re-train your model.
#
# ### Question 1
#
# **Question:** Describe your CNN-RNN architecture in detail.  With this architecture in mind, how did you select the values of the variables in Task 1?  If you consulted a research paper detailing a successful implementation of an image captioning model, please provide the reference.
#
# **Answer:** The CNN is the pre-trained ResNet-50 architecture provided by Udacity and described in the Preliminaries notebook. The RNN decoder follows the architecture described in the paper referenced above (arxiv:1411.4555). The paper specifies values for several hyperparameters (vocab_threshold=5, embed_size=hidden_size=512) .
# batch_size = 32. Using a minibatch size of 32 allows us to speed up the computations and reducing the variance (since we are averaging over i used minibatch 32.
#
#
#
# ### (Optional) Task #2
#
# Note that we have provided a recommended image transform `transform_train` for pre-processing the training images, but you are welcome (and encouraged!) to modify it as you wish.  When modifying this transform, keep in mind that:
# - the images in the dataset have varying heights and widths, and
# - if using a pre-trained model, you must perform the corresponding appropriate normalization.
#
# ### Question 2
#
# **Question:** How did you select the transform in `transform_train`?  If you left the transform at its provided value, why do you think that it is a good choice for your CNN architecture?
#
# **Answer:** The input of the CNN-encoder accepts an image of size (224 x 224 x 3), hence this is the final size of the image we are aiming for. Before doing that, we can augment our training data by randomly cropping an area of the image after resizing the image to 256. We also use a horizontal flip to augment our data with a probability of 0.5 and then convert the image to a Tensor. Finally we normalize the image by the values used for the ImageNet-dataset so that we are consistent with the pre-trained model.
#
# ### Task #3
#
# Next, you will specify a Python list containing the learnable parameters of the model.  For instance, if you decide to make all weights in the decoder trainable, but only want to train the weights in the embedding layer of the encoder, then you should set `params` to something like:
# ```
# params = list(decoder.parameters()) + list(encoder.embed.parameters())
# ```
#
# ### Question 3
#
# **Question:** How did you select the trainable parameters of your architecture?  Why do you think this is a good choice?
#
# **Answer:** The CNN-encoder is taken from a pre-trained model so that we do not need to retrain the model from scratch. However to respond to our task, we to modified the last fully-connected layer to adapt the network to our task (which is not to classify 1000 classes as in ImageNet, but rather, transforming our input image into a feature vector).
# As of the RNN-decoder, we are training it from scratch, so we take all of the parameters to be able to train all of the weights in the decoder.
#
# ### Task #4
#
# Finally, you will select an [optimizer](http://pytorch.org/docs/master/optim.html#torch.optim.Optimizer).
#
# ### Question 4
#
# **Question:** How did you select the optimizer used to train your model?
#
# **Answer:**

# %%
import torch
import torch.nn as nn
from torchvision import transforms
import sys
sys.path.append('/opt/cocoapi/PythonAPI')
from pycocotools.coco import COCO
from data_loader import get_loader
import math


## TODO #1: Select appropriate values for the Python variables below.
batch_size = 32          # batch size
vocab_threshold = 6        # minimum word count threshold
vocab_from_file = True    # if True, load existing vocab file
embed_size = 512           # dimensionality of image and word embeddings
hidden_size = 512.          # number of features in hidden state of the RNN decoder
num_epochs = 3             # number of training epochs
save_every = 1             # determines frequency of saving model weights
print_every = 100          # determines window for printing average loss
log_file = 'training_log.txt'       # name of file with saved training loss and perplexity

# (Optional) TODO #2: Amend the image transform below.
transform_train = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

# Build data loader.
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=vocab_from_file)
# Out:
# Vocabulary successfully loaded from vocab.pkl file!
# loading annotations into memory...
# Done (t=0.93s)
# creating index...
#   0%|          | 803/414113 [00:00<01:48, 3812.21it/s]
# index created!
# Obtaining caption lengths...
# 100%|██████████| 414113/414113 [01:33<00:00, 4407.12it/s]

# %%
from model import EncoderCNN, DecoderRNN
num_layers=1

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)

# Initialize the encoder and decoder. 
encoder = EncoderCNN(embed_size)
print(embed_size)
print(hidden_size)
print(vocab_size)
decoder = DecoderRNN(embed_size, int(hidden_size), vocab_size)

# Move models to GPU if CUDA is available. 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
encoder.to(device)
decoder.to(device)

# Define the loss function. 
criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()

# TODO #3: Specify the learnable parameters of the model.
# params = list(decoder.parameters()) + list(encoder.embed.parameters()) + list(encoder.bn.parameters())
params = list(decoder.parameters()) + list(encoder.embed.parameters())

# TODO #4: Define the optimizer.
optimizer = torch.optim.Adam(params, lr=0.001, betas=(0.9, 0.999), eps=1e-08)

# Set the total number of training steps per epoch.
total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)
# Out:
# 512
# 512.0
# 9955
# i am in init

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Train your Model
#
# Once you have executed the code cell in **Step 1**, the training procedure below should run without issue.
#
# It is completely fine to leave the code cell below as-is without modifications to train your model.  However, if you would like to modify the code used to train the model below, you must ensure that your changes are easily parsed by your reviewer.  In other words, make sure to provide appropriate comments to describe how your code works!
#
# You may find it useful to load saved weights to resume training.  In that case, note the names of the files containing the encoder and decoder weights that you'd like to load (`encoder_file` and `decoder_file`).  Then you can load the weights by using the lines below:
#
# ```python
# # Load pre-trained weights before resuming training.
# encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
# decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))
# ```
#
# While trying out parameters, make sure to take extensive notes and record the settings that you used in your various training runs.  In particular, you don't want to encounter a situation where you've trained a model for several hours but can't remember what settings you used :).
#
# ### A Note on Tuning Hyperparameters
#
# To figure out how well your model is doing, you can look at how the training loss and perplexity evolve during training - and for the purposes of this project, you are encouraged to amend the hyperparameters based on this information.
#
# However, this will not tell you if your model is overfitting to the training data, and, unfortunately, overfitting is a problem that is commonly encountered when training image captioning models.
#
# For this project, you need not worry about overfitting. **This project does not have strict requirements regarding the performance of your model**, and you just need to demonstrate that your model has learned **_something_** when you generate captions on the test data.  For now, we strongly encourage you to train your model for the suggested 3 epochs without worrying about performance; then, you should immediately transition to the next notebook in the sequence (**3_Inference.ipynb**) to see how your model performs on the test data.  If your model needs to be changed, you can come back to this notebook, amend hyperparameters (if necessary), and re-train the model.
#
# That said, if you would like to go above and beyond in this project, you can read about some approaches to minimizing overfitting in section 4.3.1 of [this paper](http://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=7505636).  In the next (optional) step of this notebook, we provide some guidance for assessing the performance on the validation dataset.

# %%
import torch.utils.data as data
import numpy as np
import os
import requests
import time

# Open the training log file.
f = open(log_file, 'w')

old_time = time.time()
response = requests.request("GET", 
                            "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token", 
                            headers={"Metadata-Flavor":"Google"})

for epoch in range(1, num_epochs+1):
    
    for i_step in range(1, total_step+1):
        
        if time.time() - old_time > 60:
            old_time = time.time()
            requests.request("POST", 
                             "https://nebula.udacity.com/api/v1/remote/keep-alive", 
                             headers={'Authorization': "STAR " + response.text})
        
        # Randomly sample a caption length, and sample indices with that length.
        indices = data_loader.dataset.get_train_indices()
        # Create and assign a batch sampler to retrieve a batch with the sampled indices.
        new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
        data_loader.batch_sampler.sampler = new_sampler
        
        # Obtain the batch.
        images, captions = next(iter(data_loader))

        # Move batch of images and captions to GPU if CUDA is available.
        images = images.to(device)
        captions = captions.to(device)
        
        # Zero the gradients.
        decoder.zero_grad()
        encoder.zero_grad()
        
        # Pass the inputs through the CNN-RNN model.
        features = encoder(images)
        outputs = decoder(features, captions)
        
        # Calculate the batch loss.
        loss = criterion(outputs.view(-1, vocab_size), captions.view(-1))
        
        # Backward pass.
        loss.backward()
        
        # Update the parameters in the optimizer.
        optimizer.step()
            
        # Get training statistics.
        stats = 'Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Perplexity: %5.4f' % (epoch, num_epochs, i_step, total_step, loss.item(), np.exp(loss.item()))
        
        # Print training statistics (on same line).
        print('\r' + stats, end="")
        sys.stdout.flush()
        
        # Print training statistics to file.
        f.write(stats + '\n')
        f.flush()
        
        # Print training statistics (on different line).
        if i_step % print_every == 0:
            print('\r' + stats)
            
    # Save the weights.
    if epoch % save_every == 0:
        torch.save(decoder.state_dict(), os.path.join('./models', 'decoder-%d.pkl' % epoch))
        torch.save(encoder.state_dict(), os.path.join('./models', 'encoder-%d.pkl' % epoch))

# Close the training log file.
f.close()
# Out:
# hello
# there
# Epoch [1/3], Step [1/12942], Loss: 9.2026, Perplexity: 9922.9282hello
# there
# Epoch [1/3], Step [2/12942], Loss: 8.9626, Perplexity: 7805.5717hello
# there
# Epoch [1/3], Step [3/12942], Loss: 8.7470, Perplexity: 6291.6268hello
# there
# Epoch [1/3], Step [4/12942], Loss: 8.4390, Perplexity: 4624.0705hello
# there
# Epoch [1/3], Step [5/12942], Loss: 8.1753, Perplexity: 3552.0886hello
# there
# Epoch [1/3], Step [6/12942], Loss: 7.4953, Perplexity: 1799.6466hello
# there
# Epoch [1/3], Step [7/12942], Loss: 6.9196, Perplexity: 1011.8688hello
# there
# Epoch [1/3], Step [8/12942], Loss: 6.2667, Perplexity: 526.7414hello
# there
# Epoch [1/3], Step [9/12942], Loss: 5.9764, Perplexity: 394.0011hello
# there
# Epoch [1/3], Step [10/12942], Loss: 5.2615, Perplexity: 192.7620hello
# there
# Epoch [1/3], Step [11/12942], Loss: 5.1396, Perplexity: 170.6410hello
# there
# Epoch [1/3], Step [12/12942], Loss: 5.5891, Perplexity: 267.4890hello
# there
# Epoch [1/3], Step [13/12942], Loss: 4.7953, Perplexity: 120.9417hello
# there
# Epoch [1/3], Step [14/12942], Loss: 5.0875, Perplexity: 161.9904hello
# there
# Epoch [1/3], Step [15/12942], Loss: 5.0025, Perplexity: 148.7832hello
# there
# Epoch [1/3], Step [16/12942], Loss: 4.9534, Perplexity: 141.6544hello
# there
# Epoch [1/3], Step [17/12942], Loss: 4.7481, Perplexity: 115.3592hello
# there
# Epoch [1/3], Step [18/12942], Loss: 4.8398, Perplexity: 126.4459hello
# there
# Epoch [1/3], Step [19/12942], Loss: 4.5800, Perplexity: 97.5126hello
# there
# Epoch [1/3], Step [20/12942], Loss: 4.5666, Perplexity: 96.2163hello
# there
# Epoch [1/3], Step [21/12942], Loss: 4.9569, Perplexity: 142.1472hello
# there
# Epoch [1/3], Step [22/12942], Loss: 4.9873, Perplexity: 146.5391hello
# there
# Epoch [1/3], Step [23/12942], Loss: 4.7423, Perplexity: 114.6926hello
# there
# Epoch [1/3], Step [24/12942], Loss: 4.5178, Perplexity: 91.6301hello
# there
# Epoch [1/3], Step [25/12942], Loss: 5.7472, Perplexity: 313.3144hello
# there
# Epoch [1/3], Step [26/12942], Loss: 4.5512, Perplexity: 94.7416hello
# there
# Epoch [1/3], Step [27/12942], Loss: 4.5665, Perplexity: 96.2076hello
# there
# Epoch [1/3], Step [28/12942], Loss: 5.0734, Perplexity: 159.7161hello
# there
# Epoch [1/3], Step [29/12942], Loss: 4.5883, Perplexity: 98.3258hello
# there
# Epoch [1/3], Step [30/12942], Loss: 4.5351, Perplexity: 93.2295hello
# there
# Epoch [1/3], Step [31/12942], Loss: 4.6114, Perplexity: 100.6247hello
# there
# Epoch [1/3], Step [32/12942], Loss: 4.5262, Perplexity: 92.4027hello
# there
# Epoch [1/3], Step [33/12942], Loss: 4.5197, Perplexity: 91.8118hello
# there
# Epoch [1/3], Step [34/12942], Loss: 4.2673, Perplexity: 71.3313hello
# there
# Epoch [1/3], Step [35/12942], Loss: 4.5024, Perplexity: 90.2297hello
# there
# Epoch [1/3], Step [36/12942], Loss: 4.5157, Perplexity: 91.4424hello
# there
# Epoch [1/3], Step [37/12942], Loss: 4.4512, Perplexity: 85.7296hello
# there
# Epoch [1/3], Step [38/12942], Loss: 4.4317, Perplexity: 84.0760hello
# there
# Epoch [1/3], Step [39/12942], Loss: 4.3989, Perplexity: 81.3608hello
# there
# Epoch [1/3], Step [40/12942], Loss: 4.2291, Perplexity: 68.6553hello
# there
# Epoch [1/3], Step [41/12942], Loss: 4.1677, Perplexity: 64.5682hello
# there
# Epoch [1/3], Step [42/12942], Loss: 4.4407, Perplexity: 84.8321hello
# there
# Epoch [1/3], Step [43/12942], Loss: 4.0717, Perplexity: 58.6581hello
# there
# Epoch [1/3], Step [44/12942], Loss: 4.4119, Perplexity: 82.4222hello
# there
# Epoch [1/3], Step [45/12942], Loss: 3.9624, Perplexity: 52.5817hello
# there
# Epoch [1/3], Step [46/12942], Loss: 4.2730, Perplexity: 71.7341hello
# there
# Epoch [1/3], Step [47/12942], Loss: 4.5894, Perplexity: 98.4331hello
# there
# Epoch [1/3], Step [48/12942], Loss: 5.7074, Perplexity: 301.1007hello
# there
# Epoch [1/3], Step [49/12942], Loss: 4.1026, Perplexity: 60.4946hello
# there
# Epoch [1/3], Step [50/12942], Loss: 4.4296, Perplexity: 83.8995hello
# there
# Epoch [1/3], Step [51/12942], Loss: 4.0928, Perplexity: 59.9055hello
# there
# Epoch [1/3], Step [52/12942], Loss: 4.1185, Perplexity: 61.4646hello
# there
# Epoch [1/3], Step [53/12942], Loss: 4.0603, Perplexity: 57.9905hello
# there
# Epoch [1/3], Step [54/12942], Loss: 3.8631, Perplexity: 47.6128hello
# there
# Epoch [1/3], Step [55/12942], Loss: 4.3858, Perplexity: 80.3047hello
# there
# Epoch [1/3], Step [56/12942], Loss: 4.3328, Perplexity: 76.1581hello
# there
# Epoch [1/3], Step [57/12942], Loss: 4.2727, Perplexity: 71.7157hello
# there
# Epoch [1/3], Step [58/12942], Loss: 4.0108, Perplexity: 55.1896hello
# there
# Epoch [1/3], Step [59/12942], Loss: 3.8470, Perplexity: 46.8506hello
# there
# Epoch [1/3], Step [60/12942], Loss: 4.1859, Perplexity: 65.7520hello
# there
# Epoch [1/3], Step [61/12942], Loss: 3.9431, Perplexity: 51.5797hello
# there
# Epoch [1/3], Step [62/12942], Loss: 4.1198, Perplexity: 61.5474hello
# there
# Epoch [1/3], Step [63/12942], Loss: 3.9075, Perplexity: 49.7729hello
# there
# Epoch [1/3], Step [64/12942], Loss: 4.1138, Perplexity: 61.1763hello
# there
# Epoch [1/3], Step [65/12942], Loss: 4.1840, Perplexity: 65.6248hello
# there
# Epoch [1/3], Step [66/12942], Loss: 4.2292, Perplexity: 68.6626hello
# there
# Epoch [1/3], Step [67/12942], Loss: 3.8287, Perplexity: 46.0032hello
# there
# Epoch [1/3], Step [68/12942], Loss: 3.9746, Perplexity: 53.2311hello
# there
# Epoch [1/3], Step [69/12942], Loss: 4.0507, Perplexity: 57.4363hello
# there
# Epoch [1/3], Step [70/12942], Loss: 4.0699, Perplexity: 58.5492hello
# there
# Epoch [1/3], Step [71/12942], Loss: 4.3714, Perplexity: 79.1518hello
# there
# Epoch [1/3], Step [72/12942], Loss: 4.0061, Perplexity: 54.9328hello
# there
# Epoch [1/3], Step [73/12942], Loss: 4.2707, Perplexity: 71.5739hello
# there
# Epoch [1/3], Step [74/12942], Loss: 4.0755, Perplexity: 58.8800hello
# there
# Epoch [1/3], Step [75/12942], Loss: 3.7162, Perplexity: 41.1091hello
# there
# Epoch [1/3], Step [76/12942], Loss: 4.1481, Perplexity: 63.3124hello
# there
# Epoch [1/3], Step [77/12942], Loss: 4.1745, Perplexity: 65.0065hello
# there
# Epoch [1/3], Step [78/12942], Loss: 4.0595, Perplexity: 57.9436hello
# there
# Epoch [1/3], Step [79/12942], Loss: 4.3361, Perplexity: 76.4090hello
# there
# Epoch [1/3], Step [80/12942], Loss: 3.9920, Perplexity: 54.1606hello
# there
# Epoch [1/3], Step [81/12942], Loss: 4.3294, Perplexity: 75.8995hello
# there
# Epoch [1/3], Step [82/12942], Loss: 4.0758, Perplexity: 58.8998hello
# there
# Epoch [1/3], Step [83/12942], Loss: 3.8584, Perplexity: 47.3898hello
# there
# Epoch [1/3], Step [84/12942], Loss: 4.2938, Perplexity: 73.2460hello
# there
# Epoch [1/3], Step [85/12942], Loss: 4.4525, Perplexity: 85.8417hello
# there
# Epoch [1/3], Step [86/12942], Loss: 3.7454, Perplexity: 42.3243hello
# there
# Epoch [1/3], Step [87/12942], Loss: 4.4216, Perplexity: 83.2256hello
# there
# Epoch [1/3], Step [88/12942], Loss: 3.6318, Perplexity: 37.7814hello
# there
# Epoch [1/3], Step [89/12942], Loss: 3.9918, Perplexity: 54.1504hello
# there
# Epoch [1/3], Step [90/12942], Loss: 3.8341, Perplexity: 46.2504hello
# there
# Epoch [1/3], Step [91/12942], Loss: 3.7980, Perplexity: 44.6112hello
# there
# Epoch [1/3], Step [92/12942], Loss: 3.8461, Perplexity: 46.8109hello
# there
# Epoch [1/3], Step [93/12942], Loss: 3.9328, Perplexity: 51.0480hello
# there
# Epoch [1/3], Step [94/12942], Loss: 3.9649, Perplexity: 52.7148hello
# there
# Epoch [1/3], Step [95/12942], Loss: 3.7053, Perplexity: 40.6636hello
# there
# Epoch [1/3], Step [96/12942], Loss: 3.9333, Perplexity: 51.0749hello
# there
# Epoch [1/3], Step [97/12942], Loss: 3.8645, Perplexity: 47.6811hello
# there
# Epoch [1/3], Step [98/12942], Loss: 4.0628, Perplexity: 58.1375hello
# there
# Epoch [1/3], Step [99/12942], Loss: 4.7517, Perplexity: 115.7787hello
# there
# Epoch [1/3], Step [100/12942], Loss: 3.7576, Perplexity: 42.8474
# hello
# there
# Epoch [1/3], Step [101/12942], Loss: 4.0975, Perplexity: 60.1886hello
# there
# Epoch [1/3], Step [102/12942], Loss: 4.2113, Perplexity: 67.4455hello
# there
# Epoch [1/3], Step [103/12942], Loss: 3.8384, Perplexity: 46.4510hello
# there
# Epoch [1/3], Step [104/12942], Loss: 3.9959, Perplexity: 54.3759hello
# there
# Epoch [1/3], Step [105/12942], Loss: 3.9412, Perplexity: 51.4799hello
# there
# Epoch [1/3], Step [106/12942], Loss: 3.5778, Perplexity: 35.7964hello
# there
# Epoch [1/3], Step [107/12942], Loss: 3.8013, Perplexity: 44.7598hello
# there
# Epoch [1/3], Step [108/12942], Loss: 3.5809, Perplexity: 35.9060hello
# there
# Epoch [1/3], Step [109/12942], Loss: 4.2681, Perplexity: 71.3836hello
# there
# Epoch [1/3], Step [110/12942], Loss: 3.8207, Perplexity: 45.6374hello
# there
# Epoch [1/3], Step [111/12942], Loss: 4.0588, Perplexity: 57.9070hello
# there
# Epoch [1/3], Step [112/12942], Loss: 3.8704, Perplexity: 47.9593hello
# there
# Epoch [1/3], Step [113/12942], Loss: 3.8483, Perplexity: 46.9130hello
# there
# Epoch [1/3], Step [114/12942], Loss: 3.8831, Perplexity: 48.5762hello
# there
# Epoch [1/3], Step [115/12942], Loss: 4.3667, Perplexity: 78.7867hello
# there
# Epoch [1/3], Step [116/12942], Loss: 3.5098, Perplexity: 33.4404hello
# there
# Epoch [1/3], Step [117/12942], Loss: 3.4982, Perplexity: 33.0550hello
# there
# Epoch [1/3], Step [118/12942], Loss: 3.5602, Perplexity: 35.1693hello
# there
# Epoch [1/3], Step [119/12942], Loss: 3.8353, Perplexity: 46.3065hello
# there
# Epoch [1/3], Step [120/12942], Loss: 3.6518, Perplexity: 38.5451hello
# there
# Epoch [1/3], Step [121/12942], Loss: 4.2451, Perplexity: 69.7648hello
# there
# Epoch [1/3], Step [122/12942], Loss: 3.5676, Perplexity: 35.4298hello
# there
# Epoch [1/3], Step [123/12942], Loss: 3.4378, Perplexity: 31.1169hello
# there
# Epoch [1/3], Step [124/12942], Loss: 3.5787, Perplexity: 35.8279hello
# there
# Epoch [1/3], Step [125/12942], Loss: 3.6209, Perplexity: 37.3697hello
# there
# Epoch [1/3], Step [126/12942], Loss: 3.8961, Perplexity: 49.2084hello
# there
# Epoch [1/3], Step [127/12942], Loss: 4.0047, Perplexity: 54.8552hello
# there
# Epoch [1/3], Step [128/12942], Loss: 3.9804, Perplexity: 53.5410hello
# there
# Epoch [1/3], Step [129/12942], Loss: 3.6141, Perplexity: 37.1180hello
# there
# Epoch [1/3], Step [130/12942], Loss: 3.7705, Perplexity: 43.4028hello
# there
# Epoch [1/3], Step [131/12942], Loss: 3.7735, Perplexity: 43.5326hello
# there
# Epoch [1/3], Step [132/12942], Loss: 3.5743, Perplexity: 35.6693hello
# there
# Epoch [1/3], Step [133/12942], Loss: 3.7233, Perplexity: 41.4004hello
# there
# Epoch [1/3], Step [134/12942], Loss: 3.7847, Perplexity: 44.0238hello
# there
# Epoch [1/3], Step [135/12942], Loss: 3.5999, Perplexity: 36.5943hello
# there
# Epoch [1/3], Step [136/12942], Loss: 3.7341, Perplexity: 41.8501hello
# there
# Epoch [1/3], Step [137/12942], Loss: 3.7773, Perplexity: 43.6971hello
# there
# Epoch [1/3], Step [138/12942], Loss: 3.7951, Perplexity: 44.4839hello
# there
# Epoch [1/3], Step [139/12942], Loss: 3.6142, Perplexity: 37.1203hello
# there
# Epoch [1/3], Step [140/12942], Loss: 3.8991, Perplexity: 49.3592hello
# there
# Epoch [1/3], Step [141/12942], Loss: 3.6420, Perplexity: 38.1691hello
# there
# Epoch [1/3], Step [142/12942], Loss: 3.4824, Perplexity: 32.5364hello
# there
# Epoch [1/3], Step [143/12942], Loss: 3.6131, Perplexity: 37.0804hello
# there
# Epoch [1/3], Step [144/12942], Loss: 3.6864, Perplexity: 39.9024hello
# there
# Epoch [1/3], Step [145/12942], Loss: 3.7252, Perplexity: 41.4816hello
# there
# Epoch [1/3], Step [146/12942], Loss: 3.8600, Perplexity: 47.4658hello
# there
# Epoch [1/3], Step [147/12942], Loss: 4.6674, Perplexity: 106.4210hello
# there
# Epoch [1/3], Step [148/12942], Loss: 3.3422, Perplexity: 28.2803hello
# there
# Epoch [1/3], Step [149/12942], Loss: 3.4428, Perplexity: 31.2751hello
# there
# Epoch [1/3], Step [150/12942], Loss: 3.6294, Perplexity: 37.6886hello
# there
# Epoch [1/3], Step [151/12942], Loss: 3.9561, Perplexity: 52.2518hello
# there
# Epoch [1/3], Step [152/12942], Loss: 3.3912, Perplexity: 29.7030hello
# there
# Epoch [1/3], Step [153/12942], Loss: 3.6809, Perplexity: 39.6836hello
# there
# Epoch [1/3], Step [154/12942], Loss: 4.8919, Perplexity: 133.2101hello
# there
# Epoch [1/3], Step [155/12942], Loss: 3.3780, Perplexity: 29.3110hello
# there
# Epoch [1/3], Step [156/12942], Loss: 3.9517, Perplexity: 52.0244hello
# there
# Epoch [1/3], Step [157/12942], Loss: 3.7446, Perplexity: 42.2919hello
# there
# Epoch [1/3], Step [158/12942], Loss: 3.7186, Perplexity: 41.2070hello
# there
# Epoch [1/3], Step [159/12942], Loss: 3.9294, Perplexity: 50.8789hello
# there
# Epoch [1/3], Step [160/12942], Loss: 3.7280, Perplexity: 41.5942hello
# there
# Epoch [1/3], Step [161/12942], Loss: 3.9170, Perplexity: 50.2485hello
# there
# Epoch [1/3], Step [162/12942], Loss: 3.2623, Perplexity: 26.1089hello
# there
# Epoch [1/3], Step [163/12942], Loss: 3.7430, Perplexity: 42.2265hello
# there
# Epoch [1/3], Step [164/12942], Loss: 3.5920, Perplexity: 36.3069hello
# there
# Epoch [1/3], Step [165/12942], Loss: 3.3627, Perplexity: 28.8667hello
# there
# Epoch [1/3], Step [166/12942], Loss: 3.5173, Perplexity: 33.6936hello
# there
# Epoch [1/3], Step [167/12942], Loss: 3.7377, Perplexity: 42.0008hello
# there
# Epoch [1/3], Step [168/12942], Loss: 4.0313, Perplexity: 56.3357hello
# there
# Epoch [1/3], Step [169/12942], Loss: 3.5152, Perplexity: 33.6219hello
# there
# Epoch [1/3], Step [170/12942], Loss: 3.4985, Perplexity: 33.0655hello
# there
# Epoch [1/3], Step [171/12942], Loss: 3.4141, Perplexity: 30.3881hello
# there
# Epoch [1/3], Step [172/12942], Loss: 3.6684, Perplexity: 39.1899hello
# there
# Epoch [1/3], Step [173/12942], Loss: 3.8267, Perplexity: 45.9108hello
# there
# Epoch [1/3], Step [174/12942], Loss: 3.2977, Perplexity: 27.0502hello
# there
# Epoch [1/3], Step [175/12942], Loss: 3.4009, Perplexity: 29.9905hello
# there
# Epoch [1/3], Step [176/12942], Loss: 3.5768, Perplexity: 35.7605hello
# there
# Epoch [1/3], Step [177/12942], Loss: 3.5343, Perplexity: 34.2726hello
# there
# Epoch [1/3], Step [178/12942], Loss: 3.6876, Perplexity: 39.9484hello
# there
# Epoch [1/3], Step [179/12942], Loss: 3.4578, Perplexity: 31.7458hello
# there
# Epoch [1/3], Step [180/12942], Loss: 3.1973, Perplexity: 24.4664hello
# there
# Epoch [1/3], Step [181/12942], Loss: 3.7018, Perplexity: 40.5190hello
# there
# Epoch [1/3], Step [182/12942], Loss: 3.4526, Perplexity: 31.5837hello
# there
# Epoch [1/3], Step [183/12942], Loss: 4.0681, Perplexity: 58.4433hello
# there
# Epoch [1/3], Step [184/12942], Loss: 3.6854, Perplexity: 39.8595hello
# there
# Epoch [1/3], Step [185/12942], Loss: 3.4319, Perplexity: 30.9352hello
# there
# Epoch [1/3], Step [186/12942], Loss: 3.3352, Perplexity: 28.0830hello
# there
# Epoch [1/3], Step [187/12942], Loss: 3.3896, Perplexity: 29.6540hello
# there
# Epoch [1/3], Step [188/12942], Loss: 4.3123, Perplexity: 74.6097hello
# there
# Epoch [1/3], Step [189/12942], Loss: 3.5306, Perplexity: 34.1442hello
# there
# Epoch [1/3], Step [190/12942], Loss: 3.4024, Perplexity: 30.0373hello
# there
# Epoch [1/3], Step [191/12942], Loss: 3.3980, Perplexity: 29.9031hello
# there
# Epoch [1/3], Step [192/12942], Loss: 3.7115, Perplexity: 40.9154hello
# there
# Epoch [1/3], Step [193/12942], Loss: 3.7005, Perplexity: 40.4660hello
# there
# Epoch [1/3], Step [194/12942], Loss: 3.5879, Perplexity: 36.1583hello
# there
# Epoch [1/3], Step [195/12942], Loss: 3.5616, Perplexity: 35.2186hello
# there
# Epoch [1/3], Step [196/12942], Loss: 3.4311, Perplexity: 30.9114hello
# there
# Epoch [1/3], Step [197/12942], Loss: 3.4524, Perplexity: 31.5762hello
# there
# Epoch [1/3], Step [198/12942], Loss: 3.8456, Perplexity: 46.7879hello
# there
# Epoch [1/3], Step [199/12942], Loss: 3.3671, Perplexity: 28.9950hello
# there
# Epoch [1/3], Step [200/12942], Loss: 3.5837, Perplexity: 36.0058
# hello
# there
# Epoch [1/3], Step [201/12942], Loss: 3.4896, Perplexity: 32.7740hello
# there
# Epoch [1/3], Step [202/12942], Loss: 3.3262, Perplexity: 27.8334hello
# there
# Epoch [1/3], Step [203/12942], Loss: 3.3712, Perplexity: 29.1122hello
# there
# Epoch [1/3], Step [204/12942], Loss: 3.7137, Perplexity: 41.0048hello
# there
# Epoch [1/3], Step [205/12942], Loss: 3.6494, Perplexity: 38.4510hello
# there
# Epoch [1/3], Step [206/12942], Loss: 3.2972, Perplexity: 27.0361hello
# there
# Epoch [1/3], Step [207/12942], Loss: 3.6193, Perplexity: 37.3107hello
# there
# Epoch [1/3], Step [208/12942], Loss: 3.6021, Perplexity: 36.6753hello
# there
# Epoch [1/3], Step [209/12942], Loss: 3.7166, Perplexity: 41.1250hello
# there
# Epoch [1/3], Step [210/12942], Loss: 3.6425, Perplexity: 38.1873hello
# there
# Epoch [1/3], Step [211/12942], Loss: 3.5451, Perplexity: 34.6434hello
# there
# Epoch [1/3], Step [212/12942], Loss: 3.2775, Perplexity: 26.5097hello
# there
# Epoch [1/3], Step [213/12942], Loss: 3.7539, Perplexity: 42.6889hello
# there
# Epoch [1/3], Step [214/12942], Loss: 3.8223, Perplexity: 45.7098hello
# there
# Epoch [1/3], Step [215/12942], Loss: 3.4080, Perplexity: 30.2045hello
# there
# Epoch [1/3], Step [216/12942], Loss: 3.2755, Perplexity: 26.4563hello
# there
# Epoch [1/3], Step [217/12942], Loss: 3.9496, Perplexity: 51.9172hello
# there
# Epoch [1/3], Step [218/12942], Loss: 4.1562, Perplexity: 63.8260hello
# there
# Epoch [1/3], Step [219/12942], Loss: 3.4787, Perplexity: 32.4191hello
# there
# Epoch [1/3], Step [220/12942], Loss: 3.5938, Perplexity: 36.3738hello
# there
# Epoch [1/3], Step [221/12942], Loss: 3.6436, Perplexity: 38.2278hello
# there
# Epoch [1/3], Step [222/12942], Loss: 3.6349, Perplexity: 37.8989hello
# there
# Epoch [1/3], Step [223/12942], Loss: 3.7760, Perplexity: 43.6429hello
# there
# Epoch [1/3], Step [224/12942], Loss: 3.5711, Perplexity: 35.5545hello
# there
# Epoch [1/3], Step [225/12942], Loss: 3.3864, Perplexity: 29.5599hello
# there
# Epoch [1/3], Step [226/12942], Loss: 3.5268, Perplexity: 34.0163hello
# there
# Epoch [1/3], Step [227/12942], Loss: 3.1970, Perplexity: 24.4593hello
# there
# Epoch [1/3], Step [228/12942], Loss: 3.3082, Perplexity: 27.3354hello
# there
# Epoch [1/3], Step [229/12942], Loss: 3.8022, Perplexity: 44.7976hello
# there
# Epoch [1/3], Step [230/12942], Loss: 3.5365, Perplexity: 34.3477hello
# there
# Epoch [1/3], Step [231/12942], Loss: 3.5037, Perplexity: 33.2386hello
# there
# Epoch [1/3], Step [232/12942], Loss: 3.3467, Perplexity: 28.4097hello
# there
# Epoch [1/3], Step [233/12942], Loss: 3.5358, Perplexity: 34.3225hello
# there
# Epoch [1/3], Step [234/12942], Loss: 3.3335, Perplexity: 28.0368hello
# there
# Epoch [1/3], Step [235/12942], Loss: 3.3530, Perplexity: 28.5870hello
# there
# Epoch [1/3], Step [236/12942], Loss: 3.6205, Perplexity: 37.3551hello
# there
# Epoch [1/3], Step [237/12942], Loss: 3.9467, Perplexity: 51.7658hello
# there
# Epoch [1/3], Step [238/12942], Loss: 3.0053, Perplexity: 20.1917hello
# there
# Epoch [1/3], Step [239/12942], Loss: 3.1540, Perplexity: 23.4285hello
# there
# Epoch [1/3], Step [240/12942], Loss: 3.6134, Perplexity: 37.0934hello
# there
# Epoch [1/3], Step [241/12942], Loss: 3.6420, Perplexity: 38.1676hello
# there
# Epoch [1/3], Step [242/12942], Loss: 3.4057, Perplexity: 30.1354hello
# there
# Epoch [1/3], Step [243/12942], Loss: 3.4487, Perplexity: 31.4602hello
# there
# Epoch [1/3], Step [244/12942], Loss: 3.7256, Perplexity: 41.4978hello
# there
# Epoch [1/3], Step [245/12942], Loss: 3.2785, Perplexity: 26.5364hello
# there
# Epoch [1/3], Step [246/12942], Loss: 3.3598, Perplexity: 28.7830hello
# there
# Epoch [1/3], Step [247/12942], Loss: 3.9022, Perplexity: 49.5122hello
# there
# Epoch [1/3], Step [248/12942], Loss: 3.4750, Perplexity: 32.2974hello
# there
# Epoch [1/3], Step [249/12942], Loss: 3.4429, Perplexity: 31.2780hello
# there
# Epoch [1/3], Step [250/12942], Loss: 3.7707, Perplexity: 43.4093hello
# there
# Epoch [1/3], Step [251/12942], Loss: 3.7995, Perplexity: 44.6785hello
# there
# Epoch [1/3], Step [252/12942], Loss: 3.3407, Perplexity: 28.2376hello
# there
# Epoch [1/3], Step [253/12942], Loss: 3.4444, Perplexity: 31.3256hello
# there
# Epoch [1/3], Step [254/12942], Loss: 3.4877, Perplexity: 32.7096hello
# there
# Epoch [1/3], Step [255/12942], Loss: 3.4164, Perplexity: 30.4609hello
# there
# Epoch [1/3], Step [256/12942], Loss: 3.2678, Perplexity: 26.2533hello
# there
# Epoch [1/3], Step [257/12942], Loss: 3.4474, Perplexity: 31.4191hello
# there
# Epoch [1/3], Step [258/12942], Loss: 3.3546, Perplexity: 28.6343hello
# there
# Epoch [1/3], Step [259/12942], Loss: 3.4329, Perplexity: 30.9664hello
# there
# Epoch [1/3], Step [260/12942], Loss: 3.3861, Perplexity: 29.5517hello
# there
# Epoch [1/3], Step [261/12942], Loss: 3.1147, Perplexity: 22.5278hello
# there
# Epoch [1/3], Step [262/12942], Loss: 3.5760, Perplexity: 35.7305hello
# there
# Epoch [1/3], Step [263/12942], Loss: 3.3759, Perplexity: 29.2499hello
# there
# Epoch [1/3], Step [264/12942], Loss: 3.6784, Perplexity: 39.5843hello
# there
# Epoch [1/3], Step [265/12942], Loss: 3.8254, Perplexity: 45.8525hello
# there
# Epoch [1/3], Step [266/12942], Loss: 4.0371, Perplexity: 56.6643hello
# there
# Epoch [1/3], Step [267/12942], Loss: 3.6959, Perplexity: 40.2805hello
# there
# Epoch [1/3], Step [268/12942], Loss: 3.3788, Perplexity: 29.3356hello
# there
# Epoch [1/3], Step [269/12942], Loss: 3.5414, Perplexity: 34.5156hello
# there
# Epoch [1/3], Step [270/12942], Loss: 3.6257, Perplexity: 37.5520hello
# there
# Epoch [1/3], Step [271/12942], Loss: 3.5670, Perplexity: 35.4108hello
# there
# Epoch [1/3], Step [272/12942], Loss: 3.2513, Perplexity: 25.8237hello
# there
# Epoch [1/3], Step [273/12942], Loss: 3.5016, Perplexity: 33.1685hello
# there
# Epoch [1/3], Step [274/12942], Loss: 3.7437, Perplexity: 42.2551hello
# there
# Epoch [1/3], Step [275/12942], Loss: 3.4177, Perplexity: 30.4998hello
# there
# Epoch [1/3], Step [276/12942], Loss: 3.2579, Perplexity: 25.9938hello
# there
# Epoch [1/3], Step [277/12942], Loss: 3.5752, Perplexity: 35.7018hello
# there
# Epoch [1/3], Step [278/12942], Loss: 3.8169, Perplexity: 45.4639hello
# there
# Epoch [1/3], Step [279/12942], Loss: 3.2575, Perplexity: 25.9848hello
# there
# Epoch [1/3], Step [280/12942], Loss: 2.9413, Perplexity: 18.9413hello
# there
# Epoch [1/3], Step [281/12942], Loss: 3.3192, Perplexity: 27.6375hello
# there
# Epoch [1/3], Step [282/12942], Loss: 3.3078, Perplexity: 27.3241hello
# there
# Epoch [1/3], Step [283/12942], Loss: 3.7520, Perplexity: 42.6042hello
# there
# Epoch [1/3], Step [284/12942], Loss: 3.4315, Perplexity: 30.9220hello
# there
# Epoch [1/3], Step [285/12942], Loss: 3.2448, Perplexity: 25.6565hello
# there
# Epoch [1/3], Step [286/12942], Loss: 3.5854, Perplexity: 36.0668hello
# there
# Epoch [1/3], Step [287/12942], Loss: 3.2413, Perplexity: 25.5667hello
# there
# Epoch [1/3], Step [288/12942], Loss: 3.1086, Perplexity: 22.3893hello
# there
# Epoch [1/3], Step [289/12942], Loss: 3.6059, Perplexity: 36.8134hello
# there
# Epoch [1/3], Step [290/12942], Loss: 3.5359, Perplexity: 34.3253hello
# there
# Epoch [1/3], Step [291/12942], Loss: 3.4885, Perplexity: 32.7369hello
# there
# Epoch [1/3], Step [292/12942], Loss: 3.4716, Perplexity: 32.1896hello
# there
# Epoch [1/3], Step [293/12942], Loss: 3.1217, Perplexity: 22.6840hello
# there
# Epoch [1/3], Step [294/12942], Loss: 3.2301, Perplexity: 25.2815hello
# there
# Epoch [1/3], Step [295/12942], Loss: 3.3111, Perplexity: 27.4140hello
# there
# Epoch [1/3], Step [296/12942], Loss: 3.2040, Perplexity: 24.6305hello
# there
# Epoch [1/3], Step [297/12942], Loss: 3.6488, Perplexity: 38.4301hello
# there
# Epoch [1/3], Step [298/12942], Loss: 3.4023, Perplexity: 30.0321hello
# there
# Epoch [1/3], Step [299/12942], Loss: 3.4073, Perplexity: 30.1848hello
# there
# Epoch [1/3], Step [300/12942], Loss: 3.3129, Perplexity: 27.4657
# hello
# there
# Epoch [1/3], Step [301/12942], Loss: 3.2281, Perplexity: 25.2316hello
# there
# Epoch [1/3], Step [302/12942], Loss: 3.7939, Perplexity: 44.4310hello
# there
# Epoch [1/3], Step [303/12942], Loss: 3.3432, Perplexity: 28.3097hello
# there
# Epoch [1/3], Step [304/12942], Loss: 3.7186, Perplexity: 41.2082hello
# there
# Epoch [1/3], Step [305/12942], Loss: 3.6171, Perplexity: 37.2279hello
# there
# Epoch [1/3], Step [306/12942], Loss: 3.4329, Perplexity: 30.9657hello
# there
# Epoch [1/3], Step [307/12942], Loss: 3.4163, Perplexity: 30.4574hello
# there
# Epoch [1/3], Step [308/12942], Loss: 3.0674, Perplexity: 21.4850hello
# there
# Epoch [1/3], Step [309/12942], Loss: 3.4370, Perplexity: 31.0921hello
# there
# Epoch [1/3], Step [310/12942], Loss: 3.0620, Perplexity: 21.3711hello
# there
# Epoch [1/3], Step [311/12942], Loss: 3.4222, Perplexity: 30.6371hello
# there
# Epoch [1/3], Step [312/12942], Loss: 3.3488, Perplexity: 28.4697hello
# there
# Epoch [1/3], Step [313/12942], Loss: 3.0877, Perplexity: 21.9257hello
# there
# Epoch [1/3], Step [314/12942], Loss: 3.6287, Perplexity: 37.6650hello
# there
# Epoch [1/3], Step [315/12942], Loss: 4.0994, Perplexity: 60.3055hello
# there
# Epoch [1/3], Step [316/12942], Loss: 3.4271, Perplexity: 30.7870hello
# there
# Epoch [1/3], Step [317/12942], Loss: 3.1198, Perplexity: 22.6407hello
# there
# Epoch [1/3], Step [318/12942], Loss: 3.0515, Perplexity: 21.1480hello
# there
# Epoch [1/3], Step [319/12942], Loss: 3.3753, Perplexity: 29.2341hello
# there
# Epoch [1/3], Step [320/12942], Loss: 3.2159, Perplexity: 24.9262hello
# there
# Epoch [1/3], Step [321/12942], Loss: 3.0462, Perplexity: 21.0348hello
# there
# Epoch [1/3], Step [322/12942], Loss: 3.5332, Perplexity: 34.2328hello
# there
# Epoch [1/3], Step [323/12942], Loss: 3.3814, Perplexity: 29.4133hello
# there
# Epoch [1/3], Step [324/12942], Loss: 3.5304, Perplexity: 34.1380hello
# there
# Epoch [1/3], Step [325/12942], Loss: 3.2954, Perplexity: 26.9875hello
# there
# Epoch [1/3], Step [326/12942], Loss: 3.2795, Perplexity: 26.5615hello
# there
# Epoch [1/3], Step [327/12942], Loss: 3.1358, Perplexity: 23.0080hello
# there
# Epoch [1/3], Step [328/12942], Loss: 3.1730, Perplexity: 23.8785hello
# there
# Epoch [1/3], Step [329/12942], Loss: 3.1409, Perplexity: 23.1249hello
# there
# Epoch [1/3], Step [330/12942], Loss: 3.0079, Perplexity: 20.2451hello
# there
# Epoch [1/3], Step [331/12942], Loss: 3.4288, Perplexity: 30.8391hello
# there
# Epoch [1/3], Step [332/12942], Loss: 3.6359, Perplexity: 37.9361hello
# there
# Epoch [1/3], Step [333/12942], Loss: 3.1888, Perplexity: 24.2599hello
# there
# Epoch [1/3], Step [334/12942], Loss: 3.2494, Perplexity: 25.7742hello
# there
# Epoch [1/3], Step [335/12942], Loss: 3.3031, Perplexity: 27.1961hello
# there
# Epoch [1/3], Step [336/12942], Loss: 4.2659, Perplexity: 71.2266hello
# there
# Epoch [1/3], Step [337/12942], Loss: 3.4764, Perplexity: 32.3428hello
# there
# Epoch [1/3], Step [338/12942], Loss: 3.6913, Perplexity: 40.0982hello
# there
# Epoch [1/3], Step [339/12942], Loss: 3.0358, Perplexity: 20.8177hello
# there
# Epoch [1/3], Step [340/12942], Loss: 3.8036, Perplexity: 44.8604hello
# there
# Epoch [1/3], Step [341/12942], Loss: 3.4270, Perplexity: 30.7851hello
# there
# Epoch [1/3], Step [342/12942], Loss: 3.3190, Perplexity: 27.6318hello
# there
# Epoch [1/3], Step [343/12942], Loss: 3.3584, Perplexity: 28.7421hello
# there
# Epoch [1/3], Step [344/12942], Loss: 3.1415, Perplexity: 23.1382hello
# there
# Epoch [1/3], Step [345/12942], Loss: 3.2121, Perplexity: 24.8304hello
# there
# Epoch [1/3], Step [346/12942], Loss: 3.0847, Perplexity: 21.8599hello
# there
# Epoch [1/3], Step [347/12942], Loss: 3.3175, Perplexity: 27.5919hello
# there
# Epoch [1/3], Step [348/12942], Loss: 3.1102, Perplexity: 22.4266hello
# there
# Epoch [1/3], Step [349/12942], Loss: 3.0681, Perplexity: 21.5005hello
# there
# Epoch [1/3], Step [350/12942], Loss: 3.4349, Perplexity: 31.0294hello
# there
# Epoch [1/3], Step [351/12942], Loss: 3.9779, Perplexity: 53.4048hello
# there
# Epoch [1/3], Step [352/12942], Loss: 3.1882, Perplexity: 24.2458hello
# there
# Epoch [1/3], Step [353/12942], Loss: 3.4925, Perplexity: 32.8692hello
# there
# Epoch [1/3], Step [354/12942], Loss: 3.2096, Perplexity: 24.7695hello
# there
# Epoch [1/3], Step [355/12942], Loss: 3.0191, Perplexity: 20.4733hello
# there
# Epoch [1/3], Step [356/12942], Loss: 3.3391, Perplexity: 28.1931hello
# there
# Epoch [1/3], Step [357/12942], Loss: 3.1979, Perplexity: 24.4821hello
# there
# Epoch [1/3], Step [358/12942], Loss: 2.8587, Perplexity: 17.4388hello
# there
# Epoch [1/3], Step [359/12942], Loss: 3.5163, Perplexity: 33.6607hello
# there
# Epoch [1/3], Step [360/12942], Loss: 3.2785, Perplexity: 26.5368hello
# there
# Epoch [1/3], Step [361/12942], Loss: 4.0080, Perplexity: 55.0354hello
# there
# Epoch [1/3], Step [362/12942], Loss: 3.1794, Perplexity: 24.0314hello
# there
# Epoch [1/3], Step [363/12942], Loss: 3.4170, Perplexity: 30.4767hello
# there
# Epoch [1/3], Step [364/12942], Loss: 3.8123, Perplexity: 45.2524hello
# there
# Epoch [1/3], Step [365/12942], Loss: 3.4180, Perplexity: 30.5073hello
# there
# Epoch [1/3], Step [366/12942], Loss: 3.1153, Perplexity: 22.5392hello
# there
# Epoch [1/3], Step [367/12942], Loss: 3.4956, Perplexity: 32.9715hello
# there
# Epoch [1/3], Step [368/12942], Loss: 3.7094, Perplexity: 40.8283hello
# there
# Epoch [1/3], Step [369/12942], Loss: 3.4157, Perplexity: 30.4380hello
# there
# Epoch [1/3], Step [370/12942], Loss: 3.0232, Perplexity: 20.5569hello
# there
# Epoch [1/3], Step [371/12942], Loss: 3.2837, Perplexity: 26.6752hello
# there
# Epoch [1/3], Step [372/12942], Loss: 3.5930, Perplexity: 36.3442hello
# there
# Epoch [1/3], Step [373/12942], Loss: 3.5720, Perplexity: 35.5866hello
# there
# Epoch [1/3], Step [374/12942], Loss: 3.5361, Perplexity: 34.3333hello
# there
# Epoch [1/3], Step [375/12942], Loss: 3.3082, Perplexity: 27.3363hello
# there
# Epoch [1/3], Step [376/12942], Loss: 2.9287, Perplexity: 18.7031hello
# there
# Epoch [1/3], Step [377/12942], Loss: 3.6772, Perplexity: 39.5342hello
# there
# Epoch [1/3], Step [378/12942], Loss: 3.3179, Perplexity: 27.6030hello
# there
# Epoch [1/3], Step [379/12942], Loss: 3.3114, Perplexity: 27.4224hello
# there
# Epoch [1/3], Step [380/12942], Loss: 3.5942, Perplexity: 36.3873hello
# there
# Epoch [1/3], Step [381/12942], Loss: 3.3484, Perplexity: 28.4566hello
# there
# Epoch [1/3], Step [382/12942], Loss: 3.4041, Perplexity: 30.0858hello
# there
# Epoch [1/3], Step [383/12942], Loss: 3.4284, Perplexity: 30.8283hello
# there
# Epoch [1/3], Step [384/12942], Loss: 3.2584, Perplexity: 26.0069hello
# there
# Epoch [1/3], Step [385/12942], Loss: 4.0760, Perplexity: 58.9082hello
# there
# Epoch [1/3], Step [386/12942], Loss: 3.2833, Perplexity: 26.6625hello
# there
# Epoch [1/3], Step [387/12942], Loss: 3.4114, Perplexity: 30.3078hello
# there
# Epoch [1/3], Step [388/12942], Loss: 3.6737, Perplexity: 39.3970hello
# there
# Epoch [1/3], Step [389/12942], Loss: 3.1224, Perplexity: 22.7008hello
# there
# Epoch [1/3], Step [390/12942], Loss: 3.5411, Perplexity: 34.5042hello
# there
# Epoch [1/3], Step [391/12942], Loss: 2.9853, Perplexity: 19.7918hello
# there
# Epoch [1/3], Step [392/12942], Loss: 3.2414, Perplexity: 25.5682hello
# there
# Epoch [1/3], Step [393/12942], Loss: 2.8752, Perplexity: 17.7291hello
# there
# Epoch [1/3], Step [394/12942], Loss: 3.5290, Perplexity: 34.0900hello
# there
# Epoch [1/3], Step [395/12942], Loss: 3.6248, Perplexity: 37.5171hello
# there
# Epoch [1/3], Step [396/12942], Loss: 3.2186, Perplexity: 24.9919hello
# there
# Epoch [1/3], Step [397/12942], Loss: 3.4082, Perplexity: 30.2104hello
# there
# Epoch [1/3], Step [398/12942], Loss: 3.0215, Perplexity: 20.5224hello
# there
# Epoch [1/3], Step [399/12942], Loss: 2.9967, Perplexity: 20.0185hello
# there
# Epoch [1/3], Step [400/12942], Loss: 3.1202, Perplexity: 22.6508
# hello
# there
# Epoch [1/3], Step [401/12942], Loss: 3.3951, Perplexity: 29.8180hello
# there
# Epoch [1/3], Step [402/12942], Loss: 3.1625, Perplexity: 23.6307hello
# there
# Epoch [1/3], Step [403/12942], Loss: 3.6455, Perplexity: 38.3012hello
# there
# Epoch [1/3], Step [404/12942], Loss: 3.2892, Perplexity: 26.8206hello
# there
# Epoch [1/3], Step [405/12942], Loss: 3.3799, Perplexity: 29.3669hello
# there
# Epoch [1/3], Step [406/12942], Loss: 3.3631, Perplexity: 28.8795hello
# there
# Epoch [1/3], Step [407/12942], Loss: 3.4435, Perplexity: 31.2971hello
# there
# Epoch [1/3], Step [408/12942], Loss: 3.2282, Perplexity: 25.2336hello
# there
# Epoch [1/3], Step [409/12942], Loss: 3.0782, Perplexity: 21.7186hello
# there
# Epoch [1/3], Step [410/12942], Loss: 3.7351, Perplexity: 41.8911hello
# there
# Epoch [1/3], Step [411/12942], Loss: 2.9614, Perplexity: 19.3250hello
# there
# Epoch [1/3], Step [412/12942], Loss: 3.1940, Perplexity: 24.3865hello
# there
# Epoch [1/3], Step [413/12942], Loss: 3.6703, Perplexity: 39.2656hello
# there
# Epoch [1/3], Step [414/12942], Loss: 3.3102, Perplexity: 27.3900hello
# there
# Epoch [1/3], Step [415/12942], Loss: 3.1963, Perplexity: 24.4418hello
# there
# Epoch [1/3], Step [416/12942], Loss: 3.5173, Perplexity: 33.6939hello
# there
# Epoch [1/3], Step [417/12942], Loss: 3.6449, Perplexity: 38.2796hello
# there
# Epoch [1/3], Step [418/12942], Loss: 3.2179, Perplexity: 24.9765hello
# there
# Epoch [1/3], Step [419/12942], Loss: 3.1844, Perplexity: 24.1521hello
# there
# Epoch [1/3], Step [420/12942], Loss: 2.9317, Perplexity: 18.7595hello
# there
# Epoch [1/3], Step [421/12942], Loss: 2.9112, Perplexity: 18.3781hello
# there
# Epoch [1/3], Step [422/12942], Loss: 3.0619, Perplexity: 21.3686hello
# there
# Epoch [1/3], Step [423/12942], Loss: 3.0717, Perplexity: 21.5779hello
# there
# Epoch [1/3], Step [424/12942], Loss: 3.0388, Perplexity: 20.8801hello
# there
# Epoch [1/3], Step [425/12942], Loss: 3.2341, Perplexity: 25.3836hello
# there
# Epoch [1/3], Step [426/12942], Loss: 3.0311, Perplexity: 20.7199hello
# there
# Epoch [1/3], Step [427/12942], Loss: 3.3122, Perplexity: 27.4448hello
# there
# Epoch [1/3], Step [428/12942], Loss: 3.1635, Perplexity: 23.6543hello
# there
# Epoch [1/3], Step [429/12942], Loss: 3.0329, Perplexity: 20.7570hello
# there
# Epoch [1/3], Step [430/12942], Loss: 3.4375, Perplexity: 31.1092hello
# there
# Epoch [1/3], Step [431/12942], Loss: 3.1790, Perplexity: 24.0226hello
# there
# Epoch [1/3], Step [432/12942], Loss: 3.3188, Perplexity: 27.6276hello
# there
# Epoch [1/3], Step [433/12942], Loss: 3.1248, Perplexity: 22.7549hello
# there
# Epoch [1/3], Step [434/12942], Loss: 3.2466, Perplexity: 25.7031hello
# there
# Epoch [1/3], Step [435/12942], Loss: 3.1701, Perplexity: 23.8100hello
# there
# Epoch [1/3], Step [436/12942], Loss: 3.0333, Perplexity: 20.7656hello
# there
# Epoch [1/3], Step [437/12942], Loss: 3.8187, Perplexity: 45.5467hello
# there
# Epoch [1/3], Step [438/12942], Loss: 3.3182, Perplexity: 27.6097hello
# there
# Epoch [1/3], Step [439/12942], Loss: 2.8893, Perplexity: 17.9799hello
# there
# Epoch [1/3], Step [440/12942], Loss: 3.1171, Perplexity: 22.5818hello
# there
# Epoch [1/3], Step [441/12942], Loss: 3.2530, Perplexity: 25.8684hello
# there
# Epoch [1/3], Step [442/12942], Loss: 3.0739, Perplexity: 21.6266hello
# there
# Epoch [1/3], Step [443/12942], Loss: 3.5129, Perplexity: 33.5440hello
# there
# Epoch [1/3], Step [444/12942], Loss: 3.5111, Perplexity: 33.4843hello
# there
# Epoch [1/3], Step [445/12942], Loss: 3.1904, Perplexity: 24.2986hello
# there
# Epoch [1/3], Step [446/12942], Loss: 3.0256, Perplexity: 20.6069hello
# there
# Epoch [1/3], Step [447/12942], Loss: 3.1445, Perplexity: 23.2090hello
# there
# Epoch [1/3], Step [448/12942], Loss: 3.6329, Perplexity: 37.8242hello
# there
# Epoch [1/3], Step [449/12942], Loss: 3.2205, Perplexity: 25.0396hello
# there
# Epoch [1/3], Step [450/12942], Loss: 3.1687, Perplexity: 23.7757hello
# there
# Epoch [1/3], Step [451/12942], Loss: 3.1969, Perplexity: 24.4570hello
# there
# Epoch [1/3], Step [452/12942], Loss: 3.5714, Perplexity: 35.5680hello
# there
# Epoch [1/3], Step [453/12942], Loss: 3.0198, Perplexity: 20.4864hello
# there
# Epoch [1/3], Step [454/12942], Loss: 3.4089, Perplexity: 30.2325hello
# there
# Epoch [1/3], Step [455/12942], Loss: 3.1734, Perplexity: 23.8894hello
# there
# Epoch [1/3], Step [456/12942], Loss: 3.1677, Perplexity: 23.7531hello
# there
# Epoch [1/3], Step [457/12942], Loss: 3.2271, Perplexity: 25.2070hello
# there
# Epoch [1/3], Step [458/12942], Loss: 3.1119, Perplexity: 22.4630hello
# there
# Epoch [1/3], Step [459/12942], Loss: 3.0267, Perplexity: 20.6293hello
# there
# Epoch [1/3], Step [460/12942], Loss: 3.1992, Perplexity: 24.5133hello
# there
# Epoch [1/3], Step [461/12942], Loss: 3.0180, Perplexity: 20.4513hello
# there
# Epoch [1/3], Step [462/12942], Loss: 3.5970, Perplexity: 36.4903hello
# there
# Epoch [1/3], Step [463/12942], Loss: 3.2754, Perplexity: 26.4533hello
# there
# Epoch [1/3], Step [464/12942], Loss: 3.0260, Perplexity: 20.6155hello
# there
# Epoch [1/3], Step [465/12942], Loss: 3.4508, Perplexity: 31.5267hello
# there
# Epoch [1/3], Step [466/12942], Loss: 3.2434, Perplexity: 25.6203hello
# there
# Epoch [1/3], Step [467/12942], Loss: 3.8829, Perplexity: 48.5630hello
# there
# Epoch [1/3], Step [468/12942], Loss: 2.9501, Perplexity: 19.1073hello
# there
# Epoch [1/3], Step [469/12942], Loss: 4.2385, Perplexity: 69.3010hello
# there
# Epoch [1/3], Step [470/12942], Loss: 2.8719, Perplexity: 17.6701hello
# there
# Epoch [1/3], Step [471/12942], Loss: 2.9209, Perplexity: 18.5583hello
# there
# Epoch [1/3], Step [472/12942], Loss: 3.2286, Perplexity: 25.2444hello
# there
# Epoch [1/3], Step [473/12942], Loss: 2.9739, Perplexity: 19.5689hello
# there
# Epoch [1/3], Step [474/12942], Loss: 3.1252, Perplexity: 22.7641hello
# there
# Epoch [1/3], Step [475/12942], Loss: 3.2110, Perplexity: 24.8040hello
# there
# Epoch [1/3], Step [476/12942], Loss: 2.9618, Perplexity: 19.3319hello
# there
# Epoch [1/3], Step [477/12942], Loss: 3.0697, Perplexity: 21.5364hello
# there
# Epoch [1/3], Step [478/12942], Loss: 3.3462, Perplexity: 28.3949hello
# there
# Epoch [1/3], Step [479/12942], Loss: 3.0143, Perplexity: 20.3754hello
# there
# Epoch [1/3], Step [480/12942], Loss: 3.4198, Perplexity: 30.5631hello
# there
# Epoch [1/3], Step [481/12942], Loss: 3.3415, Perplexity: 28.2610hello
# there
# Epoch [1/3], Step [482/12942], Loss: 3.0659, Perplexity: 21.4531hello
# there
# Epoch [1/3], Step [483/12942], Loss: 3.2913, Perplexity: 26.8768hello
# there
# Epoch [1/3], Step [484/12942], Loss: 3.1591, Perplexity: 23.5505hello
# there
# Epoch [1/3], Step [485/12942], Loss: 3.1724, Perplexity: 23.8658hello
# there
# Epoch [1/3], Step [486/12942], Loss: 3.5335, Perplexity: 34.2452hello
# there
# Epoch [1/3], Step [487/12942], Loss: 2.8959, Perplexity: 18.0989hello
# there
# Epoch [1/3], Step [488/12942], Loss: 3.1319, Perplexity: 22.9171hello
# there
# Epoch [1/3], Step [489/12942], Loss: 3.2670, Perplexity: 26.2318hello
# there
# Epoch [1/3], Step [490/12942], Loss: 2.9960, Perplexity: 20.0048hello
# there
# Epoch [1/3], Step [491/12942], Loss: 4.0573, Perplexity: 57.8185hello
# there
# Epoch [1/3], Step [492/12942], Loss: 2.9233, Perplexity: 18.6019hello
# there
# Epoch [1/3], Step [493/12942], Loss: 3.0046, Perplexity: 20.1772hello
# there
# Epoch [1/3], Step [494/12942], Loss: 3.1959, Perplexity: 24.4332hello
# there
# Epoch [1/3], Step [495/12942], Loss: 3.2792, Perplexity: 26.5543hello
# there
# Epoch [1/3], Step [496/12942], Loss: 2.7859, Perplexity: 16.2138hello
# there
# Epoch [1/3], Step [497/12942], Loss: 3.1165, Perplexity: 22.5677hello
# there
# Epoch [1/3], Step [498/12942], Loss: 3.4312, Perplexity: 30.9125hello
# there
# Epoch [1/3], Step [499/12942], Loss: 3.1255, Perplexity: 22.7718hello
# there
# Epoch [1/3], Step [500/12942], Loss: 3.3270, Perplexity: 27.8542
# hello
# there
# Epoch [1/3], Step [501/12942], Loss: 3.1146, Perplexity: 22.5243hello
# there
# Epoch [1/3], Step [502/12942], Loss: 3.3834, Perplexity: 29.4697hello
# there
# Epoch [1/3], Step [503/12942], Loss: 3.1531, Perplexity: 23.4095hello
# there
# Epoch [1/3], Step [504/12942], Loss: 3.1228, Perplexity: 22.7092hello
# there
# Epoch [1/3], Step [505/12942], Loss: 2.9035, Perplexity: 18.2386hello
# there
# Epoch [1/3], Step [506/12942], Loss: 3.4883, Perplexity: 32.7305hello
# there
# Epoch [1/3], Step [507/12942], Loss: 3.9071, Perplexity: 49.7531hello
# there
# Epoch [1/3], Step [508/12942], Loss: 3.1317, Perplexity: 22.9128hello
# there
# Epoch [1/3], Step [509/12942], Loss: 3.6442, Perplexity: 38.2515hello
# there
# Epoch [1/3], Step [510/12942], Loss: 2.8800, Perplexity: 17.8150hello
# there
# Epoch [1/3], Step [511/12942], Loss: 3.1602, Perplexity: 23.5748hello
# there
# Epoch [1/3], Step [512/12942], Loss: 3.0900, Perplexity: 21.9774hello
# there
# Epoch [1/3], Step [513/12942], Loss: 3.3440, Perplexity: 28.3318hello
# there
# Epoch [1/3], Step [514/12942], Loss: 3.3813, Perplexity: 29.4077hello
# there
# Epoch [1/3], Step [515/12942], Loss: 2.9461, Perplexity: 19.0308hello
# there
# Epoch [1/3], Step [516/12942], Loss: 3.1127, Perplexity: 22.4820hello
# there
# Epoch [1/3], Step [517/12942], Loss: 3.1390, Perplexity: 23.0797hello
# there
# Epoch [1/3], Step [518/12942], Loss: 3.8128, Perplexity: 45.2784hello
# there
# Epoch [1/3], Step [519/12942], Loss: 3.2968, Perplexity: 27.0259hello
# there
# Epoch [1/3], Step [520/12942], Loss: 3.2539, Perplexity: 25.8900hello
# there
# Epoch [1/3], Step [521/12942], Loss: 3.1269, Perplexity: 22.8038hello
# there
# Epoch [1/3], Step [522/12942], Loss: 3.1965, Perplexity: 24.4470hello
# there
# Epoch [1/3], Step [523/12942], Loss: 3.3331, Perplexity: 28.0251hello
# there
# Epoch [1/3], Step [524/12942], Loss: 3.2852, Perplexity: 26.7153hello
# there
# Epoch [1/3], Step [525/12942], Loss: 3.1023, Perplexity: 22.2490hello
# there
# Epoch [1/3], Step [526/12942], Loss: 3.2449, Perplexity: 25.6580hello
# there
# Epoch [1/3], Step [527/12942], Loss: 3.1538, Perplexity: 23.4258hello
# there
# Epoch [1/3], Step [528/12942], Loss: 3.1562, Perplexity: 23.4804hello
# there
# Epoch [1/3], Step [529/12942], Loss: 3.1753, Perplexity: 23.9333hello
# there
# Epoch [1/3], Step [530/12942], Loss: 2.9860, Perplexity: 19.8067hello
# there
# Epoch [1/3], Step [531/12942], Loss: 3.1809, Perplexity: 24.0692hello
# there
# Epoch [1/3], Step [532/12942], Loss: 3.4829, Perplexity: 32.5537hello
# there
# Epoch [1/3], Step [533/12942], Loss: 3.5663, Perplexity: 35.3870hello
# there
# Epoch [1/3], Step [534/12942], Loss: 3.0683, Perplexity: 21.5057hello
# there
# Epoch [1/3], Step [535/12942], Loss: 2.7671, Perplexity: 15.9127hello
# there
# Epoch [1/3], Step [536/12942], Loss: 2.9641, Perplexity: 19.3773hello
# there
# Epoch [1/3], Step [537/12942], Loss: 3.2307, Perplexity: 25.2977hello
# there
# Epoch [1/3], Step [538/12942], Loss: 2.8709, Perplexity: 17.6533hello
# there
# Epoch [1/3], Step [539/12942], Loss: 3.1261, Perplexity: 22.7856hello
# there
# Epoch [1/3], Step [540/12942], Loss: 3.3557, Perplexity: 28.6652hello
# there
# Epoch [1/3], Step [541/12942], Loss: 3.3920, Perplexity: 29.7262hello
# there
# Epoch [1/3], Step [542/12942], Loss: 3.0324, Perplexity: 20.7471hello
# there
# Epoch [1/3], Step [543/12942], Loss: 2.8863, Perplexity: 17.9261hello
# there
# Epoch [1/3], Step [544/12942], Loss: 3.2319, Perplexity: 25.3275hello
# there
# Epoch [1/3], Step [545/12942], Loss: 2.8340, Perplexity: 17.0126hello
# there
# Epoch [1/3], Step [546/12942], Loss: 2.8124, Perplexity: 16.6500hello
# there
# Epoch [1/3], Step [547/12942], Loss: 3.5346, Perplexity: 34.2825hello
# there
# Epoch [1/3], Step [548/12942], Loss: 3.1949, Perplexity: 24.4089hello
# there
# Epoch [1/3], Step [549/12942], Loss: 3.1170, Perplexity: 22.5784hello
# there
# Epoch [1/3], Step [550/12942], Loss: 3.2643, Perplexity: 26.1624hello
# there
# Epoch [1/3], Step [551/12942], Loss: 3.1038, Perplexity: 22.2824hello
# there
# Epoch [1/3], Step [552/12942], Loss: 3.4702, Perplexity: 32.1436hello
# there
# Epoch [1/3], Step [553/12942], Loss: 3.0947, Perplexity: 22.0807hello
# there
# Epoch [1/3], Step [554/12942], Loss: 3.2340, Perplexity: 25.3809hello
# there
# Epoch [1/3], Step [555/12942], Loss: 2.8614, Perplexity: 17.4855hello
# there
# Epoch [1/3], Step [556/12942], Loss: 3.0024, Perplexity: 20.1335hello
# there
# Epoch [1/3], Step [557/12942], Loss: 3.0614, Perplexity: 21.3578hello
# there
# Epoch [1/3], Step [558/12942], Loss: 3.0570, Perplexity: 21.2627hello
# there
# Epoch [1/3], Step [559/12942], Loss: 3.2271, Perplexity: 25.2060hello
# there
# Epoch [1/3], Step [560/12942], Loss: 2.9964, Perplexity: 20.0127hello
# there
# Epoch [1/3], Step [561/12942], Loss: 3.1062, Perplexity: 22.3359hello
# there
# Epoch [1/3], Step [562/12942], Loss: 3.1946, Perplexity: 24.3996hello
# there
# Epoch [1/3], Step [563/12942], Loss: 3.3137, Perplexity: 27.4873hello
# there
# Epoch [1/3], Step [564/12942], Loss: 2.7921, Perplexity: 16.3153hello
# there
# Epoch [1/3], Step [565/12942], Loss: 3.3095, Perplexity: 27.3715hello
# there
# Epoch [1/3], Step [566/12942], Loss: 2.7223, Perplexity: 15.2148hello
# there
# Epoch [1/3], Step [567/12942], Loss: 3.6307, Perplexity: 37.7402hello
# there
# Epoch [1/3], Step [568/12942], Loss: 2.8652, Perplexity: 17.5521hello
# there
# Epoch [1/3], Step [569/12942], Loss: 3.2273, Perplexity: 25.2120hello
# there
# Epoch [1/3], Step [570/12942], Loss: 3.2413, Perplexity: 25.5663hello
# there
# Epoch [1/3], Step [571/12942], Loss: 3.5415, Perplexity: 34.5173hello
# there
# Epoch [1/3], Step [572/12942], Loss: 3.1213, Perplexity: 22.6765hello
# there
# Epoch [1/3], Step [573/12942], Loss: 3.1218, Perplexity: 22.6876hello
# there
# Epoch [1/3], Step [574/12942], Loss: 3.5004, Perplexity: 33.1292hello
# there
# Epoch [1/3], Step [575/12942], Loss: 3.2904, Perplexity: 26.8541hello
# there
# Epoch [1/3], Step [576/12942], Loss: 3.0806, Perplexity: 21.7721hello
# there
# Epoch [1/3], Step [577/12942], Loss: 3.0823, Perplexity: 21.8089hello
# there
# Epoch [1/3], Step [578/12942], Loss: 3.0461, Perplexity: 21.0330hello
# there
# Epoch [1/3], Step [579/12942], Loss: 3.2637, Perplexity: 26.1463hello
# there
# Epoch [1/3], Step [580/12942], Loss: 3.2326, Perplexity: 25.3445hello
# there
# Epoch [1/3], Step [581/12942], Loss: 3.4860, Perplexity: 32.6537hello
# there
# Epoch [1/3], Step [582/12942], Loss: 3.1785, Perplexity: 24.0097hello
# there
# Epoch [1/3], Step [583/12942], Loss: 2.9436, Perplexity: 18.9843hello
# there
# Epoch [1/3], Step [584/12942], Loss: 3.4971, Perplexity: 33.0190hello
# there
# Epoch [1/3], Step [585/12942], Loss: 3.2754, Perplexity: 26.4545hello
# there
# Epoch [1/3], Step [586/12942], Loss: 3.0326, Perplexity: 20.7512hello
# there
# Epoch [1/3], Step [587/12942], Loss: 2.9978, Perplexity: 20.0416hello
# there
# Epoch [1/3], Step [588/12942], Loss: 3.2317, Perplexity: 25.3229hello
# there
# Epoch [1/3], Step [589/12942], Loss: 3.1859, Perplexity: 24.1902hello
# there
# Epoch [1/3], Step [590/12942], Loss: 3.6975, Perplexity: 40.3481hello
# there
# Epoch [1/3], Step [591/12942], Loss: 3.1981, Perplexity: 24.4856hello
# there
# Epoch [1/3], Step [592/12942], Loss: 3.2711, Perplexity: 26.3413hello
# there
# Epoch [1/3], Step [593/12942], Loss: 2.7366, Perplexity: 15.4347hello
# there
# Epoch [1/3], Step [594/12942], Loss: 2.9639, Perplexity: 19.3736hello
# there
# Epoch [1/3], Step [595/12942], Loss: 3.1102, Perplexity: 22.4258hello
# there
# Epoch [1/3], Step [596/12942], Loss: 2.9763, Perplexity: 19.6157hello
# there
# Epoch [1/3], Step [597/12942], Loss: 3.3885, Perplexity: 29.6202hello
# there
# Epoch [1/3], Step [598/12942], Loss: 3.1599, Perplexity: 23.5688hello
# there
# Epoch [1/3], Step [599/12942], Loss: 3.0369, Perplexity: 20.8404hello
# there
# Epoch [1/3], Step [600/12942], Loss: 3.4910, Perplexity: 32.8199
# hello
# there
# Epoch [1/3], Step [601/12942], Loss: 3.5844, Perplexity: 36.0309hello
# there
# Epoch [1/3], Step [602/12942], Loss: 3.4870, Perplexity: 32.6880hello
# there
# Epoch [1/3], Step [603/12942], Loss: 2.9385, Perplexity: 18.8881hello
# there
# Epoch [1/3], Step [604/12942], Loss: 3.1344, Perplexity: 22.9748hello
# there
# Epoch [1/3], Step [605/12942], Loss: 4.0161, Perplexity: 55.4829hello
# there
# Epoch [1/3], Step [606/12942], Loss: 3.1208, Perplexity: 22.6640hello
# there
# Epoch [1/3], Step [607/12942], Loss: 3.1336, Perplexity: 22.9572hello
# there
# Epoch [1/3], Step [608/12942], Loss: 3.3770, Perplexity: 29.2839hello
# there
# Epoch [1/3], Step [609/12942], Loss: 3.0741, Perplexity: 21.6299hello
# there
# Epoch [1/3], Step [610/12942], Loss: 3.3424, Perplexity: 28.2868hello
# there
# Epoch [1/3], Step [611/12942], Loss: 2.7462, Perplexity: 15.5831hello
# there
# Epoch [1/3], Step [612/12942], Loss: 3.0213, Perplexity: 20.5185hello
# there
# Epoch [1/3], Step [613/12942], Loss: 3.1131, Perplexity: 22.4896hello
# there
# Epoch [1/3], Step [614/12942], Loss: 3.1196, Perplexity: 22.6381hello
# there
# Epoch [1/3], Step [615/12942], Loss: 3.0039, Perplexity: 20.1643hello
# there
# Epoch [1/3], Step [616/12942], Loss: 3.0551, Perplexity: 21.2238hello
# there
# Epoch [1/3], Step [617/12942], Loss: 2.8473, Perplexity: 17.2420hello
# there
# Epoch [1/3], Step [618/12942], Loss: 3.0386, Perplexity: 20.8750hello
# there
# Epoch [1/3], Step [619/12942], Loss: 3.3766, Perplexity: 29.2708hello
# there
# Epoch [1/3], Step [620/12942], Loss: 3.0091, Perplexity: 20.2700hello
# there
# Epoch [1/3], Step [621/12942], Loss: 2.9706, Perplexity: 19.5044hello
# there
# Epoch [1/3], Step [622/12942], Loss: 3.2185, Perplexity: 24.9899hello
# there
# Epoch [1/3], Step [623/12942], Loss: 2.6700, Perplexity: 14.4398hello
# there
# Epoch [1/3], Step [624/12942], Loss: 2.9310, Perplexity: 18.7465hello
# there
# Epoch [1/3], Step [625/12942], Loss: 3.0698, Perplexity: 21.5379hello
# there
# Epoch [1/3], Step [626/12942], Loss: 3.0137, Perplexity: 20.3617hello
# there
# Epoch [1/3], Step [627/12942], Loss: 3.1853, Perplexity: 24.1750hello
# there
# Epoch [1/3], Step [628/12942], Loss: 3.4256, Perplexity: 30.7409hello
# there
# Epoch [1/3], Step [629/12942], Loss: 3.9203, Perplexity: 50.4143hello
# there
# Epoch [1/3], Step [630/12942], Loss: 3.0690, Perplexity: 21.5210hello
# there
# Epoch [1/3], Step [631/12942], Loss: 3.1952, Perplexity: 24.4153hello
# there
# Epoch [1/3], Step [632/12942], Loss: 3.1938, Perplexity: 24.3800hello
# there
# ...
# there
# Epoch [3/3], Step [12736/12942], Loss: 2.0453, Perplexity: 7.7316hello
# there
# Epoch [3/3], Step [12737/12942], Loss: 2.0181, Perplexity: 7.5241hello
# there
# Epoch [3/3], Step [12738/12942], Loss: 2.2015, Perplexity: 9.0382hello
# there
# Epoch [3/3], Step [12739/12942], Loss: 1.7424, Perplexity: 5.7109hello
# there
# Epoch [3/3], Step [12740/12942], Loss: 1.7433, Perplexity: 5.7164hello
# there
# Epoch [3/3], Step [12741/12942], Loss: 2.1070, Perplexity: 8.2234hello
# there
# Epoch [3/3], Step [12742/12942], Loss: 1.8894, Perplexity: 6.6157hello
# there
# Epoch [3/3], Step [12743/12942], Loss: 2.0990, Perplexity: 8.1579hello
# there
# Epoch [3/3], Step [12744/12942], Loss: 2.0476, Perplexity: 7.7492hello
# there
# Epoch [3/3], Step [12745/12942], Loss: 2.1298, Perplexity: 8.4136hello
# there
# Epoch [3/3], Step [12746/12942], Loss: 2.4235, Perplexity: 11.2852hello
# there
# Epoch [3/3], Step [12747/12942], Loss: 1.7987, Perplexity: 6.0416hello
# there
# Epoch [3/3], Step [12748/12942], Loss: 2.1540, Perplexity: 8.6191hello
# there
# Epoch [3/3], Step [12749/12942], Loss: 1.9529, Perplexity: 7.0488hello
# there
# Epoch [3/3], Step [12750/12942], Loss: 2.0176, Perplexity: 7.5200hello
# there
# Epoch [3/3], Step [12751/12942], Loss: 2.9683, Perplexity: 19.4588hello
# there
# Epoch [3/3], Step [12752/12942], Loss: 1.9766, Perplexity: 7.2179hello
# there
# Epoch [3/3], Step [12753/12942], Loss: 2.0748, Perplexity: 7.9629hello
# there
# Epoch [3/3], Step [12754/12942], Loss: 2.3082, Perplexity: 10.0566hello
# there
# Epoch [3/3], Step [12755/12942], Loss: 2.1794, Perplexity: 8.8414hello
# there
# Epoch [3/3], Step [12756/12942], Loss: 2.2435, Perplexity: 9.4259hello
# there
# Epoch [3/3], Step [12757/12942], Loss: 2.4899, Perplexity: 12.0598hello
# there
# Epoch [3/3], Step [12758/12942], Loss: 1.9824, Perplexity: 7.2599hello
# there
# Epoch [3/3], Step [12759/12942], Loss: 1.8609, Perplexity: 6.4296hello
# there
# Epoch [3/3], Step [12760/12942], Loss: 2.0956, Perplexity: 8.1306hello
# there
# Epoch [3/3], Step [12761/12942], Loss: 2.0621, Perplexity: 7.8623hello
# there
# Epoch [3/3], Step [12762/12942], Loss: 2.2653, Perplexity: 9.6339hello
# there
# Epoch [3/3], Step [12763/12942], Loss: 2.2947, Perplexity: 9.9218hello
# there
# Epoch [3/3], Step [12764/12942], Loss: 2.0786, Perplexity: 7.9935hello
# there
# Epoch [3/3], Step [12765/12942], Loss: 2.0237, Perplexity: 7.5660hello
# there
# Epoch [3/3], Step [12766/12942], Loss: 1.8547, Perplexity: 6.3897hello
# there
# Epoch [3/3], Step [12767/12942], Loss: 2.2948, Perplexity: 9.9226hello
# there
# Epoch [3/3], Step [12768/12942], Loss: 1.9764, Perplexity: 7.2170hello
# there
# Epoch [3/3], Step [12769/12942], Loss: 2.0579, Perplexity: 7.8295hello
# there
# Epoch [3/3], Step [12770/12942], Loss: 1.9471, Perplexity: 7.0081hello
# there
# Epoch [3/3], Step [12771/12942], Loss: 1.8903, Perplexity: 6.6215hello
# there
# Epoch [3/3], Step [12772/12942], Loss: 1.9564, Perplexity: 7.0737hello
# there
# Epoch [3/3], Step [12773/12942], Loss: 2.3963, Perplexity: 10.9825hello
# there
# Epoch [3/3], Step [12774/12942], Loss: 2.0552, Perplexity: 7.8087hello
# there
# Epoch [3/3], Step [12775/12942], Loss: 2.0431, Perplexity: 7.7142hello
# there
# Epoch [3/3], Step [12776/12942], Loss: 2.4802, Perplexity: 11.9437hello
# there
# Epoch [3/3], Step [12777/12942], Loss: 2.7047, Perplexity: 14.9503hello
# there
# Epoch [3/3], Step [12778/12942], Loss: 2.0250, Perplexity: 7.5759hello
# there
# Epoch [3/3], Step [12779/12942], Loss: 1.8213, Perplexity: 6.1798hello
# there
# Epoch [3/3], Step [12780/12942], Loss: 2.0657, Perplexity: 7.8910hello
# there
# Epoch [3/3], Step [12781/12942], Loss: 2.4162, Perplexity: 11.2037hello
# there
# Epoch [3/3], Step [12782/12942], Loss: 2.2307, Perplexity: 9.3064hello
# there
# Epoch [3/3], Step [12783/12942], Loss: 1.7390, Perplexity: 5.6915hello
# there
# Epoch [3/3], Step [12784/12942], Loss: 2.0589, Perplexity: 7.8374hello
# there
# Epoch [3/3], Step [12785/12942], Loss: 2.0824, Perplexity: 8.0233hello
# there
# Epoch [3/3], Step [12786/12942], Loss: 2.2245, Perplexity: 9.2490hello
# there
# Epoch [3/3], Step [12787/12942], Loss: 2.0480, Perplexity: 7.7523hello
# there
# Epoch [3/3], Step [12788/12942], Loss: 2.0888, Perplexity: 8.0749hello
# there
# Epoch [3/3], Step [12789/12942], Loss: 2.3397, Perplexity: 10.3786hello
# there
# Epoch [3/3], Step [12790/12942], Loss: 2.0142, Perplexity: 7.4946hello
# there
# Epoch [3/3], Step [12791/12942], Loss: 1.8933, Perplexity: 6.6414hello
# there
# Epoch [3/3], Step [12792/12942], Loss: 1.7183, Perplexity: 5.5751hello
# there
# Epoch [3/3], Step [12793/12942], Loss: 2.1303, Perplexity: 8.4172hello
# there
# Epoch [3/3], Step [12794/12942], Loss: 2.2062, Perplexity: 9.0808hello
# there
# Epoch [3/3], Step [12795/12942], Loss: 1.9362, Perplexity: 6.9323hello
# there
# Epoch [3/3], Step [12796/12942], Loss: 1.9945, Perplexity: 7.3486hello
# there
# Epoch [3/3], Step [12797/12942], Loss: 1.9691, Perplexity: 7.1642hello
# there
# Epoch [3/3], Step [12798/12942], Loss: 2.3239, Perplexity: 10.2159hello
# there
# Epoch [3/3], Step [12799/12942], Loss: 2.1678, Perplexity: 8.7388hello
# there
# Epoch [3/3], Step [12800/12942], Loss: 1.9255, Perplexity: 6.8584
# hello
# there
# Epoch [3/3], Step [12801/12942], Loss: 2.4022, Perplexity: 11.0474hello
# there
# Epoch [3/3], Step [12802/12942], Loss: 2.0271, Perplexity: 7.5921hello
# there
# Epoch [3/3], Step [12803/12942], Loss: 2.0069, Perplexity: 7.4404hello
# there
# Epoch [3/3], Step [12804/12942], Loss: 2.0370, Perplexity: 7.6675hello
# there
# Epoch [3/3], Step [12805/12942], Loss: 1.9170, Perplexity: 6.8008hello
# there
# Epoch [3/3], Step [12806/12942], Loss: 1.9264, Perplexity: 6.8646hello
# there
# Epoch [3/3], Step [12807/12942], Loss: 1.8233, Perplexity: 6.1925hello
# there
# Epoch [3/3], Step [12808/12942], Loss: 1.9630, Perplexity: 7.1207hello
# there
# Epoch [3/3], Step [12809/12942], Loss: 2.4673, Perplexity: 11.7910hello
# there
# Epoch [3/3], Step [12810/12942], Loss: 1.9024, Perplexity: 6.7023hello
# there
# Epoch [3/3], Step [12811/12942], Loss: 2.1776, Perplexity: 8.8250hello
# there
# Epoch [3/3], Step [12812/12942], Loss: 1.9453, Perplexity: 6.9959hello
# there
# Epoch [3/3], Step [12813/12942], Loss: 2.1459, Perplexity: 8.5499hello
# there
# Epoch [3/3], Step [12814/12942], Loss: 2.2855, Perplexity: 9.8304hello
# there
# Epoch [3/3], Step [12815/12942], Loss: 1.7611, Perplexity: 5.8190hello
# there
# Epoch [3/3], Step [12816/12942], Loss: 2.1099, Perplexity: 8.2473hello
# there
# Epoch [3/3], Step [12817/12942], Loss: 1.9084, Perplexity: 6.7420hello
# there
# Epoch [3/3], Step [12818/12942], Loss: 1.8800, Perplexity: 6.5538hello
# there
# Epoch [3/3], Step [12819/12942], Loss: 1.8254, Perplexity: 6.2053hello
# there
# Epoch [3/3], Step [12820/12942], Loss: 1.6023, Perplexity: 4.9645hello
# there
# Epoch [3/3], Step [12821/12942], Loss: 2.0576, Perplexity: 7.8270hello
# there
# Epoch [3/3], Step [12822/12942], Loss: 1.7284, Perplexity: 5.6316hello
# there
# Epoch [3/3], Step [12823/12942], Loss: 2.0321, Perplexity: 7.6301hello
# there
# Epoch [3/3], Step [12824/12942], Loss: 2.2594, Perplexity: 9.5774hello
# there
# Epoch [3/3], Step [12825/12942], Loss: 1.9064, Perplexity: 6.7289hello
# there
# Epoch [3/3], Step [12826/12942], Loss: 2.0543, Perplexity: 7.8013hello
# there
# Epoch [3/3], Step [12827/12942], Loss: 1.8944, Perplexity: 6.6486hello
# there
# Epoch [3/3], Step [12828/12942], Loss: 2.0960, Perplexity: 8.1338hello
# there
# Epoch [3/3], Step [12829/12942], Loss: 2.0738, Perplexity: 7.9551hello
# there
# Epoch [3/3], Step [12830/12942], Loss: 1.9827, Perplexity: 7.2625hello
# there
# Epoch [3/3], Step [12831/12942], Loss: 1.9289, Perplexity: 6.8818hello
# there
# Epoch [3/3], Step [12832/12942], Loss: 1.9503, Perplexity: 7.0309hello
# there
# Epoch [3/3], Step [12833/12942], Loss: 1.9111, Perplexity: 6.7603hello
# there
# Epoch [3/3], Step [12834/12942], Loss: 1.9731, Perplexity: 7.1930hello
# there
# Epoch [3/3], Step [12835/12942], Loss: 2.0166, Perplexity: 7.5129hello
# there
# Epoch [3/3], Step [12836/12942], Loss: 2.0249, Perplexity: 7.5751hello
# there
# Epoch [3/3], Step [12837/12942], Loss: 1.7470, Perplexity: 5.7373hello
# there
# Epoch [3/3], Step [12838/12942], Loss: 1.8700, Perplexity: 6.4885hello
# there
# Epoch [3/3], Step [12839/12942], Loss: 2.2238, Perplexity: 9.2426hello
# there
# Epoch [3/3], Step [12840/12942], Loss: 1.8893, Perplexity: 6.6150hello
# there
# Epoch [3/3], Step [12841/12942], Loss: 2.1108, Perplexity: 8.2550hello
# there
# Epoch [3/3], Step [12842/12942], Loss: 2.1201, Perplexity: 8.3316hello
# there
# Epoch [3/3], Step [12843/12942], Loss: 1.9794, Perplexity: 7.2384hello
# there
# Epoch [3/3], Step [12844/12942], Loss: 2.1244, Perplexity: 8.3680hello
# there
# Epoch [3/3], Step [12845/12942], Loss: 2.1874, Perplexity: 8.9121hello
# there
# Epoch [3/3], Step [12846/12942], Loss: 2.0206, Perplexity: 7.5427hello
# there
# Epoch [3/3], Step [12847/12942], Loss: 2.2257, Perplexity: 9.2598hello
# there
# Epoch [3/3], Step [12848/12942], Loss: 2.0826, Perplexity: 8.0254hello
# there
# Epoch [3/3], Step [12849/12942], Loss: 2.4128, Perplexity: 11.1649hello
# there
# Epoch [3/3], Step [12850/12942], Loss: 2.0649, Perplexity: 7.8847hello
# there
# Epoch [3/3], Step [12851/12942], Loss: 2.0227, Perplexity: 7.5587hello
# there
# Epoch [3/3], Step [12852/12942], Loss: 1.9402, Perplexity: 6.9603hello
# there
# Epoch [3/3], Step [12853/12942], Loss: 1.9839, Perplexity: 7.2707hello
# there
# Epoch [3/3], Step [12854/12942], Loss: 1.9527, Perplexity: 7.0475hello
# there
# Epoch [3/3], Step [12855/12942], Loss: 1.8698, Perplexity: 6.4868hello
# there
# Epoch [3/3], Step [12856/12942], Loss: 2.1981, Perplexity: 9.0080hello
# there
# Epoch [3/3], Step [12857/12942], Loss: 2.1127, Perplexity: 8.2705hello
# there
# Epoch [3/3], Step [12858/12942], Loss: 1.8160, Perplexity: 6.1474hello
# there
# Epoch [3/3], Step [12859/12942], Loss: 2.1849, Perplexity: 8.8898hello
# there
# Epoch [3/3], Step [12860/12942], Loss: 2.1238, Perplexity: 8.3625hello
# there
# Epoch [3/3], Step [12861/12942], Loss: 2.0462, Perplexity: 7.7381hello
# there
# Epoch [3/3], Step [12862/12942], Loss: 1.9263, Perplexity: 6.8642hello
# there
# Epoch [3/3], Step [12863/12942], Loss: 2.1468, Perplexity: 8.5573hello
# there
# Epoch [3/3], Step [12864/12942], Loss: 2.0936, Perplexity: 8.1142hello
# there
# Epoch [3/3], Step [12865/12942], Loss: 2.4529, Perplexity: 11.6225hello
# there
# Epoch [3/3], Step [12866/12942], Loss: 2.0624, Perplexity: 7.8650hello
# there
# Epoch [3/3], Step [12867/12942], Loss: 2.1228, Perplexity: 8.3548hello
# there
# Epoch [3/3], Step [12868/12942], Loss: 2.0064, Perplexity: 7.4365hello
# there
# Epoch [3/3], Step [12869/12942], Loss: 2.0548, Perplexity: 7.8050hello
# there
# Epoch [3/3], Step [12870/12942], Loss: 5.2366, Perplexity: 188.0371hello
# there
# Epoch [3/3], Step [12871/12942], Loss: 1.8271, Perplexity: 6.2157hello
# there
# Epoch [3/3], Step [12872/12942], Loss: 1.8093, Perplexity: 6.1062hello
# there
# Epoch [3/3], Step [12873/12942], Loss: 1.9437, Perplexity: 6.9848hello
# there
# Epoch [3/3], Step [12874/12942], Loss: 2.1514, Perplexity: 8.5970hello
# there
# Epoch [3/3], Step [12875/12942], Loss: 1.9880, Perplexity: 7.3010hello
# there
# Epoch [3/3], Step [12876/12942], Loss: 2.0883, Perplexity: 8.0711hello
# there
# Epoch [3/3], Step [12877/12942], Loss: 2.8362, Perplexity: 17.0500hello
# there
# Epoch [3/3], Step [12878/12942], Loss: 2.1302, Perplexity: 8.4168hello
# there
# Epoch [3/3], Step [12879/12942], Loss: 1.9911, Perplexity: 7.3232hello
# there
# Epoch [3/3], Step [12880/12942], Loss: 1.9281, Perplexity: 6.8761hello
# there
# Epoch [3/3], Step [12881/12942], Loss: 2.0262, Perplexity: 7.5852hello
# there
# Epoch [3/3], Step [12882/12942], Loss: 2.0547, Perplexity: 7.8046hello
# there
# Epoch [3/3], Step [12883/12942], Loss: 1.7402, Perplexity: 5.6987hello
# there
# Epoch [3/3], Step [12884/12942], Loss: 1.8075, Perplexity: 6.0952hello
# there
# Epoch [3/3], Step [12885/12942], Loss: 2.0349, Perplexity: 7.6516hello
# there
# Epoch [3/3], Step [12886/12942], Loss: 1.8505, Perplexity: 6.3627hello
# there
# Epoch [3/3], Step [12887/12942], Loss: 1.9308, Perplexity: 6.8952hello
# there
# Epoch [3/3], Step [12888/12942], Loss: 2.0366, Perplexity: 7.6643hello
# there
# Epoch [3/3], Step [12889/12942], Loss: 1.8900, Perplexity: 6.6196hello
# there
# Epoch [3/3], Step [12890/12942], Loss: 1.7952, Perplexity: 6.0204hello
# there
# Epoch [3/3], Step [12891/12942], Loss: 2.2366, Perplexity: 9.3617hello
# there
# Epoch [3/3], Step [12892/12942], Loss: 2.3810, Perplexity: 10.8153hello
# there
# Epoch [3/3], Step [12893/12942], Loss: 2.1060, Perplexity: 8.2150hello
# there
# Epoch [3/3], Step [12894/12942], Loss: 2.0816, Perplexity: 8.0171hello
# there
# Epoch [3/3], Step [12895/12942], Loss: 1.9621, Perplexity: 7.1143hello
# there
# Epoch [3/3], Step [12896/12942], Loss: 2.1464, Perplexity: 8.5537hello
# there
# Epoch [3/3], Step [12897/12942], Loss: 2.2067, Perplexity: 9.0857hello
# there
# Epoch [3/3], Step [12898/12942], Loss: 2.3147, Perplexity: 10.1222hello
# there
# Epoch [3/3], Step [12899/12942], Loss: 2.2957, Perplexity: 9.9311hello
# there
# Epoch [3/3], Step [12900/12942], Loss: 2.1226, Perplexity: 8.3526
# hello
# there
# Epoch [3/3], Step [12901/12942], Loss: 1.7040, Perplexity: 5.4957hello
# there
# Epoch [3/3], Step [12902/12942], Loss: 1.8879, Perplexity: 6.6056hello
# there
# Epoch [3/3], Step [12903/12942], Loss: 2.0503, Perplexity: 7.7700hello
# there
# Epoch [3/3], Step [12904/12942], Loss: 1.6852, Perplexity: 5.3934hello
# there
# Epoch [3/3], Step [12905/12942], Loss: 1.9676, Perplexity: 7.1533hello
# there
# Epoch [3/3], Step [12906/12942], Loss: 1.9914, Perplexity: 7.3261hello
# there
# Epoch [3/3], Step [12907/12942], Loss: 2.0082, Perplexity: 7.4499hello
# there
# Epoch [3/3], Step [12908/12942], Loss: 2.2472, Perplexity: 9.4613hello
# there
# Epoch [3/3], Step [12909/12942], Loss: 1.9931, Perplexity: 7.3383hello
# there
# Epoch [3/3], Step [12910/12942], Loss: 2.0912, Perplexity: 8.0944hello
# there
# Epoch [3/3], Step [12911/12942], Loss: 1.8648, Perplexity: 6.4544hello
# there
# Epoch [3/3], Step [12912/12942], Loss: 1.8112, Perplexity: 6.1180hello
# there
# Epoch [3/3], Step [12913/12942], Loss: 1.9656, Perplexity: 7.1391hello
# there
# Epoch [3/3], Step [12914/12942], Loss: 1.9802, Perplexity: 7.2442hello
# there
# Epoch [3/3], Step [12915/12942], Loss: 2.1070, Perplexity: 8.2237hello
# there
# Epoch [3/3], Step [12916/12942], Loss: 1.9844, Perplexity: 7.2745hello
# there
# Epoch [3/3], Step [12917/12942], Loss: 2.5150, Perplexity: 12.3660hello
# there
# Epoch [3/3], Step [12918/12942], Loss: 1.8836, Perplexity: 6.5774hello
# there
# Epoch [3/3], Step [12919/12942], Loss: 1.9043, Perplexity: 6.7145hello
# there
# Epoch [3/3], Step [12920/12942], Loss: 1.8366, Perplexity: 6.2749hello
# there
# Epoch [3/3], Step [12921/12942], Loss: 2.2800, Perplexity: 9.7767hello
# there
# Epoch [3/3], Step [12922/12942], Loss: 2.4593, Perplexity: 11.6968hello
# there
# Epoch [3/3], Step [12923/12942], Loss: 1.9828, Perplexity: 7.2630hello
# there
# Epoch [3/3], Step [12924/12942], Loss: 2.3140, Perplexity: 10.1147hello
# there
# Epoch [3/3], Step [12925/12942], Loss: 2.0534, Perplexity: 7.7947hello
# there
# Epoch [3/3], Step [12926/12942], Loss: 2.1095, Perplexity: 8.2440hello
# there
# Epoch [3/3], Step [12927/12942], Loss: 2.0300, Perplexity: 7.6139hello
# there
# Epoch [3/3], Step [12928/12942], Loss: 2.2504, Perplexity: 9.4919hello
# there
# Epoch [3/3], Step [12929/12942], Loss: 2.0044, Perplexity: 7.4215hello
# there
# Epoch [3/3], Step [12930/12942], Loss: 2.1281, Perplexity: 8.3991hello
# there
# Epoch [3/3], Step [12931/12942], Loss: 2.1154, Perplexity: 8.2932hello
# there
# Epoch [3/3], Step [12932/12942], Loss: 2.0358, Perplexity: 7.6582hello
# there
# Epoch [3/3], Step [12933/12942], Loss: 2.2079, Perplexity: 9.0965hello
# there
# Epoch [3/3], Step [12934/12942], Loss: 1.8323, Perplexity: 6.2483hello
# there
# Epoch [3/3], Step [12935/12942], Loss: 2.2197, Perplexity: 9.2043hello
# there
# Epoch [3/3], Step [12936/12942], Loss: 1.8832, Perplexity: 6.5745hello
# there
# Epoch [3/3], Step [12937/12942], Loss: 2.1008, Perplexity: 8.1723hello
# there
# Epoch [3/3], Step [12938/12942], Loss: 1.9094, Perplexity: 6.7491hello
# there
# Epoch [3/3], Step [12939/12942], Loss: 2.0158, Perplexity: 7.5067hello
# there
# Epoch [3/3], Step [12940/12942], Loss: 1.8280, Perplexity: 6.2212hello
# there
# Epoch [3/3], Step [12941/12942], Loss: 2.3530, Perplexity: 10.5173hello
# there
# Epoch [3/3], Step [12942/12942], Loss: 2.1789, Perplexity: 8.8363

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: (Optional) Validate your Model
#
# To assess potential overfitting, one approach is to assess performance on a validation set.  If you decide to do this **optional** task, you are required to first complete all of the steps in the next notebook in the sequence (**3_Inference.ipynb**); as part of that notebook, you will write and test code (specifically, the `sample` method in the `DecoderRNN` class) that uses your RNN decoder to generate captions.  That code will prove incredibly useful here.
#
# If you decide to validate your model, please do not edit the data loader in **data_loader.py**.  Instead, create a new file named **data_loader_val.py** containing the code for obtaining the data loader for the validation data.  You can access:
# - the validation images at filepath `'/opt/cocoapi/images/train2014/'`, and
# - the validation image caption annotation file at filepath `'/opt/cocoapi/annotations/captions_val2014.json'`.
#
# The suggested approach to validating your model involves creating a json file such as [this one](https://github.com/cocodataset/cocoapi/blob/master/results/captions_val2014_fakecap_results.json) containing your model's predicted captions for the validation images.  Then, you can write your own script or use one that you [find online](https://github.com/tylin/coco-caption) to calculate the BLEU score of your model.  You can read more about the BLEU score, along with other evaluation metrics (such as TEOR and Cider) in section 4.1 of [this paper](https://arxiv.org/pdf/1411.4555.pdf).  For more information about how to use the annotation file, check out the [website](http://cocodataset.org/#download) for the COCO dataset.

# %%
# (Optional) TODO: Validate your model.
